# %% [markdown]
# # Product Range Analysis
# ## I. Data Preprocessing & Exploratory Data Analysis

# %% [markdown]
# ## Table of Contents
#
# - [Project Overview](#overview)
# - [Data Preprocessing](#DPP)
# - [Exploratory Data Analysis](#EDA)

# %% [markdown]
# <a id='overview'></a>
# ## Overview
#
# You are given a sales transactions history data of an online store that sells household goods. Perform product range and customer segmentation analysis to help the stakeholders identify the top performing products, categories, and customers.
#
#
# ### Business Problem
# Based on the sales transactions data:
# 1. Identify the top performers: top customer, top product, and top category
# 2. Identify the customer segments based on RFM
# 3. Did higher-priced products contribute to higher sales than the lower-priced products?
# 4. Were sales higher during Christmas season (December) as compared to other months?
#
#
# ### Datasets and Attributes
#
# The original dataset contains **541909** transaction records from **2018-11-29 to 2019-12-07**. It has 7 attributes:
#
# - **InvoiceNo**: Invoice reference number uniquely assigned for each transaction. If the InvoiceNo starts with 'C', it indicates a cancellation
# - **StockCode**: Product or item code uniquely assigned to each distinct product
# - **Description**: Product or item name
# - **Quantity**: The quantities for each product or item per transaction
# - **InvoiceDate**: Invoice date and time, the day and time the transaction was generated by the system
# - **UnitPrice**: Product price per unit
# - **CustomerID**: Customer reference number uniquely assigned to each customer
#
#
# ### Project Scope
# 1. Data Preprocessing
# 2. Exploratory Data Analysis
# 3. Customer Segmentation based on RFM Metrics (using percentile ranking and K-means clustering)
# 4. Product Categorization & Product Category Analysis
# 5. Statistical Hypotheses
# 6. Insights
# 7. Dashboard

# %% [markdown]
# <a id='DPP'></a>
# ## Data Preprocessing

# %%
# Import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
# Load the dataset

sales_df = pd.read_csv("C:/Users/offic/OneDrive/Desktop/product data analysis/ecommerce_dataset_us.csv", sep='\t', parse_dates=['InvoiceDate'])
sales_df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID
# 0 2018-11-29 08:26:00       2.55     17850.0
# 1 2018-11-29 08:26:00       3.39     17850.0
# 2 2018-11-29 08:26:00       2.75     17850.0
# 3 2018-11-29 08:26:00       3.39     17850.0
# 4 2018-11-29 08:26:00       3.39     17850.0

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 28.9+ MB

# %% [markdown]
# #### Issues:
#
# - Decimal values from CustomerID should be removed.
# - CustomerID has null values.
# - CustomerID should be changed to object/string.

# %%
# Fill the missing values on CustomerID with 0, change data typer to int then to string

sales_df['CustomerID'] = sales_df['CustomerID'].fillna(0).astype('int64').astype('str')
sales_df['CustomerID'].head()
# Out:
# 0    17850
# 1    17850
# 2    17850
# 3    17850
# 4    17850
# Name: CustomerID, dtype: object

# %%
sales_df['CustomerID'].head()
# Out:
# 0    17850
# 1    17850
# 2    17850
# 3    17850
# 4    17850
# Name: CustomerID, dtype: object

# %%
sales_df.describe()
# Out:
#             Quantity                    InvoiceDate      UnitPrice
# count  541909.000000                         541909  541909.000000
# mean        9.552250  2019-07-02 13:34:57.156386560       4.611114
# min    -80995.000000            2018-11-29 08:26:00  -11062.060000
# 25%         1.000000            2019-03-26 11:34:00       1.250000
# 50%         3.000000            2019-07-17 17:17:00       2.080000
# 75%        10.000000            2019-10-17 11:27:00       4.130000
# max     80995.000000            2019-12-07 12:50:00   38970.000000
# std       218.081158                            NaN      96.759853

# %% [markdown]
# #### Observations/Notes:
# - Positive and matching negative quantities could indicate a return or cancellation of an order.
# - Transactions covered between 2008-11-29 and 2019-12-07.
# - Having negative values on UnitPrice is unusual.
# - Further investigation is needed on Quantity and UnitPrice due to outliers. Quantity's max is 80995 and mean is 9.5. UnitPrice's max is 38,970.00 and mean is 4.61.

# %%
sales_df.describe(include='object')
# Out:
#        InvoiceNo StockCode                         Description CustomerID
# count     541909    541909                              540455     541909
# unique     25900      4070                                4223       4373
# top       573585    85123A  WHITE HANGING HEART T-LIGHT HOLDER          0
# freq        1114      2313                                2369     135080

# %%
# Check for missing values

sales_df.isnull().sum()
# Out:
# InvoiceNo         0
# StockCode         0
# Description    1454
# Quantity          0
# InvoiceDate       0
# UnitPrice         0
# CustomerID        0
# dtype: int64

# %% [markdown]
# #### Observations/Notes:
# - There are 541909 InvoiceNo's, but only 25900 are unique. This means that there are multiple records bearing the same invoice number which is normal in e-commerce (eg. invoice having multiple lines).
# - Same goes for StockCode and Description. However, StockCode and Description ideally should have the same number of unique values. In this case, StockCode has 4070 unique values and Description has 4223, which could mean that there are stock codes that have multiple descriptions.
# - StockCodes can be a combination of numeric and alpha characters (e.g. 85123A).
# - There are records without description.
# - CustomerID's top or most common value is 0 (NaNs were replaced by 0's).

# %%
# Change all 0's to NaN in customer id to bring back the missing values

sales_df['CustomerID'].replace('0', np.nan, inplace = True)

# %%
# Create a LineTotal by multiplying UnitPrice and Quantity

sales_df['LineTotal'] = sales_df['Quantity'] * sales_df['UnitPrice']
sales_df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal
# 0      2018-11-29 08:26:00       2.55      17850      15.30
# 1      2018-11-29 08:26:00       3.39      17850      20.34
# 2      2018-11-29 08:26:00       2.75      17850      22.00
# 3      2018-11-29 08:26:00       3.39      17850      20.34
# 4      2018-11-29 08:26:00       3.39      17850      20.34
# ...                    ...        ...        ...        ...
# 541904 2019-12-07 12:50:00       0.85      12680      10.20
# 541905 2019-12-07 12:50:00       2.10      12680      12.60
# 541906 2019-12-07 12:50:00       4.15      12680      16.60
# 541907 2019-12-07 12:50:00       4.15      12680      16.60
# 541908 2019-12-07 12:50:00       4.95      12680      14.85
#
# [541909 rows x 8 columns]

# %%
# Check for duplicate records

sales_df.duplicated().sum()
# Out:
# np.int64(5268)

# %%
sales_df[sales_df.duplicated(keep=False)].sort_values(by=['CustomerID', 'InvoiceNo', 'StockCode'])
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 395388    571034     23239   SET OF 4 KNICK KNACK TINS POPPIES         6
# 395410    571034     23239   SET OF 4 KNICK KNACK TINS POPPIES         6
# 395371    571034     23245          SET OF 3 REGENCY CAKE TINS         4
# 395455    571034     23245          SET OF 3 REGENCY CAKE TINS         4
# 395442    571034     23494    VINTAGE DOILY DELUXE SEWING KIT          3
# ...          ...       ...                                 ...       ...
# 133118   C547725     22924       FRIDGE MAGNETS LA VIE EN ROSE       -72
# 133109   C547725     84929  ASSTD FRUIT+FLOWERS FRIDGE MAGNETS      -144
# 133110   C547725     84929  ASSTD FRUIT+FLOWERS FRIDGE MAGNETS      -144
# 235950   C557663     21121   SET/10 RED POLKADOT PARTY CANDLES       -24
# 235951   C557663     21121   SET/10 RED POLKADOT PARTY CANDLES       -24
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal
# 395388 2019-10-11 12:47:00       4.15      12359      24.90
# 395410 2019-10-11 12:47:00       4.15      12359      24.90
# 395371 2019-10-11 12:47:00       4.95      12359      19.80
# 395455 2019-10-11 12:47:00       4.95      12359      19.80
# 395442 2019-10-11 12:47:00       5.95      12359      17.85
# ...                    ...        ...        ...        ...
# 133118 2019-03-23 10:43:00       0.85        NaN     -61.20
# 133109 2019-03-23 10:43:00       0.55        NaN     -79.20
# 133110 2019-03-23 10:43:00       0.55        NaN     -79.20
# 235950 2019-06-19 17:59:00       1.25        NaN     -30.00
# 235951 2019-06-19 17:59:00       1.25        NaN     -30.00
#
# [10147 rows x 8 columns]

# %% [markdown]
# #### Observations/Notes:
# - There are 5268 duplicated records and these will be removed.

# %%
sales_df.shape
# Out:
# (541909, 8)

# %%
# Remove duplicate records

sales_df = sales_df.drop_duplicates(keep = 'first')

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 536641 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    536641 non-null  object
#  1   StockCode    536641 non-null  object
#  2   Description  535187 non-null  object
#  3   Quantity     536641 non-null  int64
#  4   InvoiceDate  536641 non-null  datetime64[ns]
#  5   UnitPrice    536641 non-null  float64
#  6   CustomerID   401604 non-null  object
#  7   LineTotal    536641 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 36.8+ MB

# %%
# Investigate records where description is null

sales_df[sales_df['Description'].isnull()]
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 622       536414     22139         NaN        56 2018-11-29 11:52:00
# 1970      536545     21134         NaN         1 2018-11-29 14:32:00
# 1971      536546     22145         NaN         1 2018-11-29 14:33:00
# 1972      536547     37509         NaN         1 2018-11-29 14:33:00
# 1987      536549    85226A         NaN         1 2018-11-29 14:34:00
# ...          ...       ...         ...       ...                 ...
# 535322    581199     84581         NaN        -2 2019-12-05 18:26:00
# 535326    581203     23406         NaN        15 2019-12-05 18:31:00
# 535332    581209     21620         NaN         6 2019-12-05 18:35:00
# 536981    581234     72817         NaN        27 2019-12-06 10:33:00
# 538554    581408     85175         NaN        20 2019-12-06 14:06:00
#
#         UnitPrice CustomerID  LineTotal
# 622           0.0        NaN        0.0
# 1970          0.0        NaN        0.0
# 1971          0.0        NaN        0.0
# 1972          0.0        NaN        0.0
# 1987          0.0        NaN        0.0
# ...           ...        ...        ...
# 535322        0.0        NaN       -0.0
# 535326        0.0        NaN        0.0
# 535332        0.0        NaN        0.0
# 536981        0.0        NaN        0.0
# 538554        0.0        NaN        0.0
#
# [1454 rows x 8 columns]

# %%
# Replace NaNs with 'Unknown' in the description column

sales_df['Description'].fillna('unknown', inplace = True)
sales_df[sales_df['Description'].isnull()]
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, LineTotal]
# Index: []

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 536641 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    536641 non-null  object
#  1   StockCode    536641 non-null  object
#  2   Description  536641 non-null  object
#  3   Quantity     536641 non-null  int64
#  4   InvoiceDate  536641 non-null  datetime64[ns]
#  5   UnitPrice    536641 non-null  float64
#  6   CustomerID   401604 non-null  object
#  7   LineTotal    536641 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 36.8+ MB

# %%
# Investigate records where customer id is null

sales_df[sales_df['CustomerID'].isnull()]
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 622       536414     22139                          unknown        56
# 1443      536544     21773  DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444      536544     21774  DECORATIVE CATS BATHROOM BOTTLE         2
# 1445      536544     21786               POLKADOT RAIN HAT          4
# 1446      536544     21787            RAIN PONCHO RETROSPOT         2
# ...          ...       ...                              ...       ...
# 541536    581498    85099B          JUMBO BAG RED RETROSPOT         5
# 541537    581498    85099C   JUMBO  BAG BAROQUE BLACK WHITE         4
# 541538    581498     85150    LADIES & GENTLEMEN METAL SIGN         1
# 541539    581498     85174                S/4 CACTI CANDLES         1
# 541540    581498       DOT                   DOTCOM POSTAGE         1
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal
# 622    2018-11-29 11:52:00       0.00        NaN       0.00
# 1443   2018-11-29 14:32:00       2.51        NaN       2.51
# 1444   2018-11-29 14:32:00       2.51        NaN       5.02
# 1445   2018-11-29 14:32:00       0.85        NaN       3.40
# 1446   2018-11-29 14:32:00       1.66        NaN       3.32
# ...                    ...        ...        ...        ...
# 541536 2019-12-07 10:26:00       4.13        NaN      20.65
# 541537 2019-12-07 10:26:00       4.13        NaN      16.52
# 541538 2019-12-07 10:26:00       4.96        NaN       4.96
# 541539 2019-12-07 10:26:00      10.79        NaN      10.79
# 541540 2019-12-07 10:26:00    1714.17        NaN    1714.17
#
# [135037 rows x 8 columns]

# %%
# How many orders (invoice numbers) without customer id?

sales_df[sales_df['CustomerID'].isnull()]['InvoiceNo'].nunique()
# Out:
# 3710

# %% [markdown]
# #### Observations/Notes:
# - There are 135037 records or 3710 orders (invoices) without customer id. The records appear to be valid transactions, these could be those customers who are not registered and purchased the products without signing up.

# %%
# Investigate invoice numbers

sales_df['InvoiceNo'].str[0].value_counts()
# Out:
# InvoiceNo
# 5    527387
# C      9251
# A         3
# Name: count, dtype: int64

# %% [markdown]
# #### Observations/Notes:
# - There are 9251 records where the invoice number starts with C and 3 records where the invoice number starts with A

# %%
# Investigate records where invoice number starts with A

sales_df[sales_df['InvoiceNo'].str[0] == 'A']
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299982   A563185         B  Adjust bad debt         1 2019-08-10 14:50:00
# 299983   A563186         B  Adjust bad debt         1 2019-08-10 14:51:00
# 299984   A563187         B  Adjust bad debt         1 2019-08-10 14:52:00
#
#         UnitPrice CustomerID  LineTotal
# 299982   11062.06        NaN   11062.06
# 299983  -11062.06        NaN  -11062.06
# 299984  -11062.06        NaN  -11062.06

# %% [markdown]
# #### Observations/Notes:
# - These records are related to bad debts adjustment and are not related to products nor a sales transaction. The records will be removed.

# %%
sales_df.shape
# Out:
# (536641, 8)

# %%
# Remove records where invoice number starts with A

sales_df = sales_df[~(sales_df['InvoiceNo'].str[0] == 'A')]

# %%
sales_df.shape
# Out:
# (536638, 8)

# %%
# Investigate records where invoice number starts with C

sales_df[sales_df['InvoiceNo'].str[0] == 'C']
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal
# 141    2018-11-29 09:41:00      27.50      14527     -27.50
# 154    2018-11-29 09:49:00       4.65      15311      -4.65
# 235    2018-11-29 10:24:00       1.65      17548     -19.80
# 236    2018-11-29 10:24:00       0.29      17548      -6.96
# 237    2018-11-29 10:24:00       0.29      17548      -6.96
# ...                    ...        ...        ...        ...
# 540449 2019-12-07 09:57:00       0.83      14397      -9.13
# 541541 2019-12-07 10:28:00     224.69      15498    -224.69
# 541715 2019-12-07 11:57:00      10.95      15311     -54.75
# 541716 2019-12-07 11:58:00       1.25      17315      -1.25
# 541717 2019-12-07 11:58:00       1.25      17315      -6.25
#
# [9251 rows x 8 columns]

# %% [markdown]
# #### Observations/Notes:
# - There are 9251 records where InvoiceNo starts with C, which indicates cancellation.

# %%
# Investigate stock codes

sales_df['StockCode'].str[0].value_counts()
# Out:
# StockCode
# 2    434001
# 8     62460
# 4     11373
# 1      7578
# 7      7151
# 3      5705
# 9      4638
# P      1260
# D       832
# 5       633
# M       566
# C       160
# 6       113
# S        62
# B        37
# A        34
# g        34
# m         1
# Name: count, dtype: int64

# %% [markdown]
# #### Observations/Notes:
# - There are records where stock codes start with P, D, M, C, S, B, A, g, and m.

# %%
# Investigate records where stock codes start with P

sales_df[sales_df['StockCode'].str[0] == 'P']
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 45        536370      POST     POSTAGE         3 2018-11-29 08:45:00
# 386       536403      POST     POSTAGE         1 2018-11-29 11:27:00
# 1123      536527      POST     POSTAGE         1 2018-11-29 13:04:00
# 5073      536840      POST     POSTAGE         1 2018-11-30 18:27:00
# 5258      536852      POST     POSTAGE         1 2018-12-01 09:51:00
# ...          ...       ...         ...       ...                 ...
# 541198    581493      POST     POSTAGE         1 2019-12-07 10:10:00
# 541216    581494      POST     POSTAGE         2 2019-12-07 10:13:00
# 541730    581570      POST     POSTAGE         1 2019-12-07 11:59:00
# 541767    581574      POST     POSTAGE         2 2019-12-07 12:09:00
# 541768    581578      POST     POSTAGE         3 2019-12-07 12:16:00
#
#         UnitPrice CustomerID  LineTotal
# 45           18.0      12583       54.0
# 386          15.0      12791       15.0
# 1123         18.0      12662       18.0
# 5073         18.0      12738       18.0
# 5258         18.0      12686       18.0
# ...           ...        ...        ...
# 541198       15.0      12423       15.0
# 541216       18.0      12518       36.0
# 541730       18.0      12662       18.0
# 541767       18.0      12526       36.0
# 541768       18.0      12713       54.0
#
# [1260 rows x 8 columns]

# %%
# Investigate records where stock codes start with D

sales_df[sales_df['StockCode'].str[0] == 'D']
# Out:
#        InvoiceNo StockCode     Description  Quantity         InvoiceDate  \
# 141      C536379         D        Discount        -1 2018-11-29 09:41:00
# 1814      536544       DOT  DOTCOM POSTAGE         1 2018-11-29 14:32:00
# 3041      536592       DOT  DOTCOM POSTAGE         1 2018-11-29 17:06:00
# 5450      536862       DOT  DOTCOM POSTAGE         1 2018-12-01 11:13:00
# 5545      536864       DOT  DOTCOM POSTAGE         1 2018-12-01 11:27:00
# ...          ...       ...             ...       ...                 ...
# 536834    581219       DOT  DOTCOM POSTAGE         1 2019-12-06 09:28:00
# 537254    581238       DOT  DOTCOM POSTAGE         1 2019-12-06 10:53:00
# 539368    581439       DOT  DOTCOM POSTAGE         1 2019-12-06 16:30:00
# 540908    581492       DOT  DOTCOM POSTAGE         1 2019-12-07 10:03:00
# 541540    581498       DOT  DOTCOM POSTAGE         1 2019-12-07 10:26:00
#
#         UnitPrice CustomerID  LineTotal
# 141         27.50      14527     -27.50
# 1814       569.77        NaN     569.77
# 3041       607.49        NaN     607.49
# 5450       254.43        NaN     254.43
# 5545       121.06        NaN     121.06
# ...           ...        ...        ...
# 536834    1008.96        NaN    1008.96
# 537254    1683.75        NaN    1683.75
# 539368     938.59        NaN     938.59
# 540908     933.17        NaN     933.17
# 541540    1714.17        NaN    1714.17
#
# [832 rows x 8 columns]

# %%
# Investigate records where stock codes start with M

sales_df[sales_df['StockCode'].str[0] == 'M']
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 2239      536569         M      Manual         1 2018-11-29 15:35:00
# 2250      536569         M      Manual         1 2018-11-29 15:35:00
# 5684      536865         M      Manual         1 2018-12-01 11:28:00
# 6798      536981         M      Manual         2 2018-12-01 14:26:00
# 7976      537077         M      Manual        12 2018-12-03 11:59:00
# ...          ...       ...         ...       ...                 ...
# 531432    580956         M      Manual         4 2019-12-04 14:23:00
# 533082   C581009         M      Manual        -1 2019-12-05 09:15:00
# 534308   C581145         M      Manual        -1 2019-12-05 13:48:00
# 538321    581405         M      Manual         3 2019-12-06 13:50:00
# 541541   C581499         M      Manual        -1 2019-12-07 10:28:00
#
#         UnitPrice CustomerID  LineTotal
# 2239         1.25      16274       1.25
# 2250        18.95      16274      18.95
# 5684         2.55        NaN       2.55
# 6798         0.85      14723       1.70
# 7976         0.42      17062       5.04
# ...           ...        ...        ...
# 531432       1.25      17841       5.00
# 533082     125.00      16971    -125.00
# 534308       9.95      17490      -9.95
# 538321       0.42      13521       1.26
# 541541     224.69      15498    -224.69
#
# [566 rows x 8 columns]

# %%
# Investigate records where stock codes start with C

sales_df[sales_df['StockCode'].str[0] == 'C']
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 1423      536540        C2         CARRIAGE         1 2018-11-29 14:05:00
# 12119     537368        C2         CARRIAGE         1 2018-12-04 12:40:00
# 12452     537378        C2         CARRIAGE         1 2018-12-04 13:06:00
# 19975     537963        C2         CARRIAGE         1 2018-12-07 11:30:00
# 20016     538002        C2         CARRIAGE         1 2018-12-07 11:48:00
# ...          ...       ...              ...       ...                 ...
# 516484    579910        C2         CARRIAGE         1 2019-11-29 08:52:00
# 518854    580124        C2         CARRIAGE         1 2019-11-29 17:12:00
# 518905    580127        C2         CARRIAGE         1 2019-11-29 17:51:00
# 524450    580555        C2         CARRIAGE         1 2019-12-03 10:18:00
# 528087   C580726      CRUK  CRUK Commission        -1 2019-12-03 17:17:00
#
#         UnitPrice CustomerID  LineTotal
# 1423        50.00      14911      50.00
# 12119       50.00      14911      50.00
# 12452       50.00      14911      50.00
# 19975       50.00      13369      50.00
# 20016       50.00      14932      50.00
# ...           ...        ...        ...
# 516484      50.00      14911      50.00
# 518854      50.00        NaN      50.00
# 518905      50.00      14911      50.00
# 524450      50.00      14911      50.00
# 528087    1100.44      14096   -1100.44
#
# [160 rows x 8 columns]

# %%
# Investigate records where stock codes start with S

sales_df[sales_df['StockCode'].str[0] == 'S']
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 14436    C537581         S     SAMPLES        -1 2018-12-05 12:03:00
# 14437    C537581         S     SAMPLES        -1 2018-12-05 12:03:00
# 96680    C544580         S     SAMPLES        -1 2019-02-19 14:25:00
# 96681    C544580         S     SAMPLES        -1 2019-02-19 14:25:00
# 96682    C544580         S     SAMPLES        -1 2019-02-19 14:25:00
# ...          ...       ...         ...       ...                 ...
# 414147   C572347         S     SAMPLES        -1 2019-10-22 11:03:00
# 419666    572849         S     SAMPLES         1 2019-10-24 12:20:00
# 480961   C577330         S     SAMPLES        -1 2019-11-16 14:16:00
# 480962   C577330         S     SAMPLES        -1 2019-11-16 14:16:00
# 480963   C577330         S     SAMPLES        -1 2019-11-16 14:16:00
#
#         UnitPrice CustomerID  LineTotal
# 431351    573586  BANK CHARGES  Bank Charges         1 2019-10-29 14:48:00
# 440745    574546  BANK CHARGES  Bank Charges         1 2019-11-02 14:59:00
# 481152   C577342  BANK CHARGES  Bank Charges        -1 2019-11-16 15:11:00
# 481153   C577343  BANK CHARGES  Bank Charges        -1 2019-11-16 15:13:00
# 506357    579137  BANK CHARGES  Bank Charges         1 2019-11-26 12:51:00
# 534008    581127  BANK CHARGES  Bank Charges         1 2019-12-05 12:45:00
#
#         UnitPrice CustomerID  LineTotal
# 4406       15.000      15823     15.000
# 14435      95.380        NaN    -95.380
# 28992     966.920        NaN   -966.920
# 62508      15.000      15939     15.000
# 64573    1050.150        NaN  -1050.150
# 90558     566.370        NaN   -566.370
# 96675     134.760        NaN   -134.760
# 96676     149.160        NaN   -149.160
# 96715     109.840        NaN   -109.840
# 112233    326.680        NaN   -326.680
# 124025     56.930        NaN    -56.930
# 152966     15.000      14606     15.000
# 166515    475.690        NaN   -475.690
# 175275     15.000      16714     15.000
# 181258    440.290        NaN   -440.290
# 193136     86.900        NaN    -86.900
# 193444     82.730        NaN    -82.730
# 227400    464.520        NaN   -464.520
# 242465     82.890        NaN    -82.890
# 273311     21.900        NaN    -21.900
# 303275    612.460        NaN   -612.460
# 313427     83.830        NaN    -83.830
# 313461     77.630        NaN    -77.630
# 327921     15.000      16904     15.000
# 345020    366.270        NaN   -366.270
# 361740     15.000      13405     15.000
# 361741      0.001      13405      0.001
# 388729    472.770        NaN   -472.770
# 389027     49.650        NaN    -49.650
# 407618     15.000      13263     15.000
# 414146     49.650        NaN    -49.650
# 431351     15.000      14704     15.000
# 440745     15.000      13651     15.000
# 481152    490.060        NaN   -490.060
# 481153     27.210        NaN    -27.210
# 506357     15.000      14704     15.000
# 534008     15.000      16271     15.000

# %%
# Investigate records where stock codes start with A

sales_df[sales_df['StockCode'].str[0] == 'A']
# Out:
#        InvoiceNo  StockCode Description  Quantity         InvoiceDate  \
# 14514    C537600  AMAZONFEE  AMAZON FEE        -1 2018-12-05 12:41:00
# 15016    C537630  AMAZONFEE  AMAZON FEE        -1 2018-12-05 15:04:00
# 15017     537632  AMAZONFEE  AMAZON FEE         1 2018-12-05 15:08:00
# 16232    C537644  AMAZONFEE  AMAZON FEE        -1 2018-12-05 15:34:00
# 16313    C537647  AMAZONFEE  AMAZON FEE        -1 2018-12-05 15:41:00
# 16356    C537651  AMAZONFEE  AMAZON FEE        -1 2018-12-05 15:49:00
# 16357    C537652  AMAZONFEE  AMAZON FEE        -1 2018-12-05 15:51:00
# 43702    C540117  AMAZONFEE  AMAZON FEE        -1 2019-01-03 09:55:00
# 43703    C540118  AMAZONFEE  AMAZON FEE        -1 2019-01-03 09:57:00
# 96844    C544587  AMAZONFEE  AMAZON FEE        -1 2019-02-19 15:07:00
# 96845    C544589  AMAZONFEE  AMAZON FEE        -1 2019-02-19 15:11:00
# 124741   C546987  AMAZONFEE  AMAZON FEE        -1 2019-03-16 12:56:00
# 163439 2019-04-17 11:37:00       8.33        NaN       8.33
# 163440 2019-04-17 11:37:00      16.67        NaN      16.67
# 178556 2019-05-04 15:54:00      41.67        NaN      41.67
# 191910 2019-05-14 16:33:00       8.33        NaN       8.33
# 192071 2019-05-14 16:37:00       8.33        NaN       8.33
# 208808 2019-05-29 15:49:00      25.00        NaN      25.00
# 228807 2019-06-14 09:04:00       0.00        NaN       0.00
# 234137 2019-06-18 15:27:00      16.67        NaN      16.67
# 239744 2019-06-22 15:45:00      41.67        NaN      41.67
# 239899 2019-06-22 15:51:00      16.67        NaN      16.67
# 245515 2019-06-28 15:56:00       8.33        NaN       8.33
# 245516 2019-06-28 15:56:00      41.67        NaN      41.67
# 281008 2019-07-25 15:12:00      33.33        NaN      33.33
# 291036 2019-08-02 16:38:00      16.67        NaN      16.67
# 297099 2019-08-08 16:51:00      25.00        NaN      25.00
# 317441 2019-08-28 10:47:00       8.33        NaN       8.33
# 317442 2019-08-28 10:47:00      25.00        NaN      25.00
# 317500 2019-08-28 10:48:00       0.00        NaN       0.00
# 317501 2019-08-28 10:48:00       0.00        NaN       0.00
# 320440 2019-08-29 15:32:00       8.33        NaN      16.66
# 322164 2019-08-31 09:26:00      25.00        NaN      25.00
# 431349 2019-10-29 14:41:00      16.67        NaN      16.67
# 536047 2019-12-06 09:20:00       8.33        NaN       8.33

# %%
# Investigate records where stock codes start with m

sales_df[sales_df['StockCode'].str[0] == 'm']
# Out:
#       InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 40383    539736         m      Manual         1 2018-12-19 15:18:00
#
#        UnitPrice CustomerID  LineTotal
# 40383       2.55        NaN       2.55

# %% [markdown]
# #### Observations/Assumptions:
# - These records are not sales transactions which will be removed:
# 1. P - Postage
# 2. D - Dotcom postage
# 3. M - Manual
# 4. C - Carriage, CRUK Commission
# 5. S - Samples
# 6. B - Bank Charges
# 7. A - Amazon fees
# 8. g - gift vouchers
# 9. m - Manual

# %%
sales_df.shape
# Out:
# (536638, 8)

# %%
# Remove records where stock codes start with P, D, M, C, S, B, A, g, and m

alpha_stock_code = ['P', 'D', 'M', 'C', 'S', 'B', 'A', 'g', 'm']
sales_df = sales_df[~(sales_df['StockCode'].str[0].isin(alpha_stock_code))]

# %%
sales_df.shape
# Out:
# (533652, 8)

# %%
# Investigate records where price is 0

sales_df[sales_df['UnitPrice'] == 0]
# Out:
#        InvoiceNo StockCode                   Description  Quantity  \
# 622       536414     22139                       unknown        56
# 1970      536545     21134                       unknown         1
# 1971      536546     22145                       unknown         1
# 1972      536547     37509                       unknown         1
# 1987      536549    85226A                       unknown         1
# ...          ...       ...                           ...       ...
# 536981    581234     72817                       unknown        27
# 538504    581406    46000M  POLYESTER FILLER PAD 45x45cm       240
# 538505    581406    46000S  POLYESTER FILLER PAD 40x40cm       300
# 538554    581408     85175                       unknown        20
# 538919    581422     23169                       smashed      -235
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal
# 622    2018-11-29 11:52:00        0.0        NaN        0.0
# 1970   2018-11-29 14:32:00        0.0        NaN        0.0
# 1971   2018-11-29 14:33:00        0.0        NaN        0.0
# 1972   2018-11-29 14:33:00        0.0        NaN        0.0
# 1987   2018-11-29 14:34:00        0.0        NaN        0.0
# ...                    ...        ...        ...        ...
# 536981 2019-12-06 10:33:00        0.0        NaN        0.0
# 538504 2019-12-06 13:58:00        0.0        NaN        0.0
# 538505 2019-12-06 13:58:00        0.0        NaN        0.0
# 538554 2019-12-06 14:06:00        0.0        NaN        0.0
# 538919 2019-12-06 15:24:00        0.0        NaN       -0.0
#
# [2480 rows x 8 columns]

# %% [markdown]
# #### Observations/Assumptions:
# - There are 2480 records where price is 0, which ultimately resulted to 0 revenue. These records will be removed.

# %%
sales_df.shape
# Out:
# (533652, 8)

# %%
# Remove records where price is 0

sales_df = sales_df[sales_df['UnitPrice'] != 0]

# %%
sales_df.shape
# Out:
# (531172, 8)

# %%
# Investigate records where price is negative

sales_df[sales_df['UnitPrice'] < 0]
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, LineTotal]
# Index: []

# %%
sales_df.describe()
# Out:
#             Quantity                    InvoiceDate      UnitPrice  \
# count  531172.000000                         531172  531172.000000
# mean        9.961487  2019-07-02 13:35:48.893541120       3.292533
# min    -80995.000000            2018-11-29 08:26:00       0.030000
# 25%         1.000000            2019-03-26 11:56:15       1.250000
# 50%         3.000000            2019-07-18 09:30:00       2.080000
# 75%        10.000000            2019-10-17 10:31:00       4.130000
# max     80995.000000            2019-12-07 12:50:00     649.500000
# std       217.014514                            NaN       4.512918
#
#            LineTotal
# count  531172.000000
# mean       18.395020
# min   -168469.600000
# 25%         3.750000
# 50%         9.900000
# 75%        17.400000
# max    168469.600000
# std       369.767571

# %%
# Investigate price levels

price_levels = sales_df.groupby(['StockCode'])['UnitPrice'].nunique().reset_index()
price_levels[price_levels['UnitPrice'] > 1]
# Out:
#      StockCode  UnitPrice
# 0        10002          3
# 1        10080          2
# 6        10125          6
# 7        10133          7
# 8        10135          7
# ...        ...        ...
# 3908    90214T          3
# 3910    90214V          4
# 3911    90214W          3
# 3912    90214Y          4
# 3913    90214Z          3
#
# [3361 rows x 2 columns]

# %% [markdown]
# #### Observations/Notes:
# - There are 3361 stock codes with more than 1 price levels.

# %%
# Determine the number of price levels 

price_levels['UnitPrice'].value_counts()
# Out:
# UnitPrice
# 4     866
# 3     822
# 1     553
# 5     531
# 2     526
# 6     292
# 7     158
# 8      71
# 9      36
# 10     23
# 11     20
# 12     10
# 13      3
# 15      2
# 14      1
# Name: count, dtype: int64

# %% [markdown]
# #### Observations/Notes:
# - It shows that there are only 553 stock codes that have 1 price level, and the other stock codes have 2 to 15 price levels

# %%
# Investigate stock code with 15 price levels

price_levels[price_levels['UnitPrice'] == 15]
# Out:
#      StockCode  UnitPrice
# 2675     47566         15
# 2851     79321         15

# %%
# Investigate records where stock code is 47566

sales_df[sales_df['StockCode'] == '47566']
# Out:
#        InvoiceNo StockCode    Description  Quantity         InvoiceDate  \
# 5535      536864     47566  PARTY BUNTING         1 2018-12-01 11:27:00
# 5656      536865     47566  PARTY BUNTING         3 2018-12-01 11:28:00
# 6022      536876     47566  PARTY BUNTING         2 2018-12-01 11:36:00
# 6572      536956     47566  PARTY BUNTING         5 2018-12-01 12:43:00
# 7904      537065     47566  PARTY BUNTING         5 2018-12-03 11:57:00
# ...          ...       ...            ...       ...                 ...
# 537784    581345     47566  PARTY BUNTING         5 2019-12-06 12:15:00
# 538825    581417     47566  PARTY BUNTING         8 2019-12-06 15:01:00
# 539027    581426     47566  PARTY BUNTING         1 2019-12-06 15:31:00
# 540534    581492     47566  PARTY BUNTING         2 2019-12-07 10:03:00
# 541318    581497     47566  PARTY BUNTING         5 2019-12-07 10:23:00
#
#         UnitPrice CustomerID  LineTotal
# 5535         9.32        NaN       9.32
# 5656         9.32        NaN      27.96
# 6022         8.47        NaN      16.94
# 6572         4.65      14210      23.25
# 7904         4.65      12567      23.25
# ...           ...        ...        ...
# 537784       4.95      17315      24.75
# 538825       4.95      13013      39.60
# 539027       4.95      17757       4.95
# 540534      10.79        NaN      21.58
# 541318      10.79        NaN      53.95
#
# [1719 rows x 8 columns]

# %%
# Show/list the different price levels for stock code 47566

sorted(sales_df[sales_df['StockCode'] == '47566']['UnitPrice'].unique())
# Out:
# [3.74,
#  3.75,
#  4.15,
#  4.3,
#  4.65,
#  4.95,
#  4.96,
#  5.79,
#  8.29,
#  8.47,
#  9.13,
#  9.32,
#  10.79,
#  12.95,
#  15.79]

# %% [markdown]
# #### Observations/Assumptions:
# - Different price levels could indicate that there may be wholesale prices and retail prices or just simply price increase but since we don't have information about the store's pricing policy - these are just assumptions and for this reason, it is not necessary to make any changes

# %%
sales_df.describe()
# Out:
#             Quantity                    InvoiceDate      UnitPrice  \
# count  531172.000000                         531172  531172.000000
# mean        9.961487  2019-07-02 13:35:48.893541120       3.292533
# min    -80995.000000            2018-11-29 08:26:00       0.030000
# 25%         1.000000            2019-03-26 11:56:15       1.250000
# 50%         3.000000            2019-07-18 09:30:00       2.080000
# 75%        10.000000            2019-10-17 10:31:00       4.130000
# max     80995.000000            2019-12-07 12:50:00     649.500000
# std       217.014514                            NaN       4.512918
#
#            LineTotal
# count  531172.000000
# mean       18.395020
# min   -168469.600000
# 25%         3.750000
# 50%         9.900000
# 75%        17.400000
# max    168469.600000
# std       369.767571

# %% [markdown]
# #### Observations/Assumptions:
# - The minimum quantity of -80995 and maximum quantity of 80995 could mean that there was an order for 80995 units and there was cancellation for the same number of units.

# %%
# Preview records with matching positive and negative quantities

sales_df[sales_df['Quantity'].abs() >= 3000]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 4287     C536757     84347  ROTATING SILVER ANGELS T-LIGHT HLDR     -9360
# 52711     540815     21108   FAIRY CAKE FLANNEL ASSORTED COLOUR      3114
# 61619     541431     23166       MEDIUM CERAMIC TOP STORAGE JAR     74215
# 61624    C541433     23166       MEDIUM CERAMIC TOP STORAGE JAR    -74215
# 74614     542504     37413                              unknown      5568
# 97432     544612     22053                EMPIRE DESIGN ROSETTE      3906
# 113580    545990     84598                                check     -3000
# 115807    546139     84988                                    ?      3000
# 115818    546152    72140F                           throw away     -5368
# 160145   C550456     21108   FAIRY CAKE FLANNEL ASSORTED COLOUR     -3114
# 160546    550461     21108   FAIRY CAKE FLANNEL ASSORTED COLOUR      3114
# 206121    554868     22197                 SMALL POPCORN HOLDER      4300
# 220843    556231    85123A                                    ?      4000
# 225528    556687     23003         Printing smudges/thrown away     -9058
# 225529    556690     23005         printing smudges/thrown away     -9600
# 225530    556691     23005         printing smudges/thrown away     -9600
# 263884    560039     20713         wrongly marked. 23343 in box     -3100
# 263885    560040     23343                  came coded as 20713      3100
# 270885    560599     18007  ESSENTIAL BALM 3.5g TIN IN ENVELOPE      3186
# 323458    565304     16259                              unknown     -3167
# 341601    566768     16045                              unknown     -3667
# 421632    573008     84077    WORLD WAR 2 GLIDERS ASSTD DESIGNS      4800
# 431381    573596    79323W               Unsaleable, destroyed.     -4830
# 433788    573995     16014          SMALL CHINESE STYLE SCISSOR      3000
# 502122    578841     84826       ASSTD DESIGN 3D PAPER STICKERS     12540
# 540421    581483     23843          PAPER CRAFT , LITTLE BIRDIE     80995
# 540422   C581484     23843          PAPER CRAFT , LITTLE BIRDIE    -80995
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal
# 4287   2018-11-30 14:23:00       0.03      15838    -280.80
# 52711  2019-01-09 12:55:00       2.10      15749    6539.40
# 61619  2019-01-16 10:01:00       1.04      12346   77183.60
# 61624  2019-01-16 10:17:00       1.04      12346  -77183.60
# 74614  2019-01-26 12:03:00       0.00        NaN       0.00
# 97432  2019-02-20 10:43:00       0.82      18087    3202.92
# 113580 2019-03-06 13:07:00       0.00        NaN      -0.00
# 115807 2019-03-07 16:35:00       0.00        NaN       0.00
# 115818 2019-03-07 17:25:00       0.00        NaN      -0.00
# 160145 2019-04-16 13:08:00       2.10      15749   -6539.40
# 160546 2019-04-16 13:20:00       2.10      15749    6539.40
# 206121 2019-05-25 10:52:00       0.72      13135    3096.00
# 220843 2019-06-07 15:04:00       0.00        NaN       0.00
# 225528 2019-06-12 10:36:00       0.00        NaN      -0.00
# 225529 2019-06-12 10:37:00       0.00        NaN      -0.00
# 225530 2019-06-12 10:37:00       0.00        NaN      -0.00
# 263884 2019-07-12 14:27:00       0.00        NaN      -0.00
# 263885 2019-07-12 14:28:00       0.00        NaN       0.00
# 270885 2019-07-17 17:04:00       0.06      14609     191.16
# 323458 2019-08-31 12:18:00       0.00        NaN      -0.00
# 341601 2019-09-12 17:53:00       0.00        NaN      -0.00
# 421632 2019-10-25 12:26:00       0.21      12901    1008.00
# 431381 2019-10-29 15:17:00       0.00        NaN      -0.00
# 433788 2019-10-31 11:24:00       0.32      16308     960.00
# 502122 2019-11-23 15:57:00       0.00      13256       0.00
# 540421 2019-12-07 09:15:00       2.08      16446  168469.60
# 540422 2019-12-07 09:27:00       2.08      16446 -168469.60

# %% [markdown]
# #### Observations/Assumptions:
# - It shows that there are 2 extremey large quantities of sales which have corresponding cancellations:
# - InvoiceNo 541431 with quantity of 74215 dated 2019-01-16 was cancelled the same day under InvoiceNo C541433
# - InvoiceNo 581483 with quantity of 80995 dated 2019-11-07 was cancelled the same day under InvoiceNo C581484
# - There are other records with matching positive and negative quantities
# - Ideally, both the original and cancelled invoices should be removed since the negative quantity will offset the positive quantity. Hence, the net effect is zero.

# %%
# Find cancellation pairs (original invoice and corresponding cancelled invoice)

sales_df.groupby([sales_df.CustomerID, sales_df.StockCode, sales_df.Quantity.abs()])\
        .filter(lambda x: (len(x.Quantity.abs()) % 2 == 0) and (x.Quantity.sum() == 0))\
        .sort_values(by=['CustomerID', 'StockCode'])
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 61619     541431     23166      MEDIUM CERAMIC TOP STORAGE JAR     74215
# 61624    C541433     23166      MEDIUM CERAMIC TOP STORAGE JAR    -74215
# 84148     543370     22839     3 TIER CAKE TIN GREEN AND CREAM         2
# 154936   C549955     22839     3 TIER CAKE TIN GREEN AND CREAM        -2
# 423970    573173     22941        CHRISTMAS LIGHTS 10 REINDEER         2
# ...          ...       ...                                 ...       ...
# 488517   C577832     23245          SET OF 3 REGENCY CAKE TINS        -4
# 453557    575485    84509A     SET OF 4 ENGLISH ROSE PLACEMATS         4
# 488516   C577832    84509A     SET OF 4 ENGLISH ROSE PLACEMATS        -4
# 453565    575485     84988  SET OF 72 PINK HEART PAPER DOILIES        12
# 488515   C577832     84988  SET OF 72 PINK HEART PAPER DOILIES       -12
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal
# 61619  2019-01-16 10:01:00       1.04      12346    77183.6
# 61624  2019-01-16 10:17:00       1.04      12346   -77183.6
# 84148  2019-02-05 14:51:00      14.95      12359       29.9
# 154936 2019-04-11 13:38:00      14.95      12359      -29.9
# 423970 2019-10-26 10:10:00       8.50      12362       17.0
# ...                    ...        ...        ...        ...
# 488517 2019-11-20 10:18:00       4.95      18274      -19.8
# 453557 2019-11-07 17:03:00       3.75      18274       15.0
# 488516 2019-11-20 10:18:00       3.75      18274      -15.0
# 453565 2019-11-07 17:03:00       1.45      18274       17.4
# 488515 2019-11-20 10:18:00       1.45      18274      -17.4
#
# [4030 rows x 8 columns]

# %% [markdown]
# #### Observations/Assumptions:
# - There are 2017 pairs of original invoice and its corresponding cancelled invoice totalling to 4034 records.
# - These are for 1:1 match - meaning for each customer, there are pairs of original invoice and cancelled invoice that have the same stock_code and matching positive/negative quantities.

# %%
# Check the number of cancelled orders

len(sales_df[sales_df['InvoiceNo'].str[0] == 'C'])
# Out:
# 8668

# %%
# Determine the number of customers whose orders have negative quantities (or customers who have cancelled orders)

cust_neg_orders = sales_df[sales_df['Quantity'] < 0]['CustomerID'].unique()
len(cust_neg_orders)
# Out:
# 1535

# %% [markdown]
# #### Observations/Assumptions:
# - There are 1535 customers whose orders have negative quantities (or cancelled orders)

# %%
# Preview list of customers whose orders have negative quantities

list(cust_neg_orders[:10])
# Out:
# ['15311',
#  '17548',
#  '17897',
#  '17841',
#  '12472',
#  nan,
#  '14092',
#  '12471',
#  '14766',
#  '14390']

# %%
def check_cancellations(df):
    """This function definition is to capture records of a customer that have:
    1. partial cancellations
    2. cancellations only (without original orders)
    3. original orders, full cancellations, and re-orders
    and will require to pass a subset of a dataframe filtered to a specific customer that has negative values in orders
    """
    for i in df['Quantity'].unique():
        
        #checking if for each negative Quantity there is the same positive Quantity
        if i < 0 and abs(i) in df['Quantity'].unique():     
            print('There are matching positive quantities for', i)
            
            #checking stockcodes that have matching positive and negative Quantity
            stockcode = list(df[df['Quantity'] == i]['StockCode'].unique())
            print('Stockcodes that have matching positive and negative quantities:', stockcode)
        
            #subsetting the possible stockcodes and pair of positive + negative Quantity
            subset_stockcode = df[df['StockCode'].isin(stockcode)]
            subset_pairs = subset_stockcode[(subset_stockcode['Quantity'] == i)|(subset_stockcode['Quantity'] == abs(i))]
        
            #iterating over each stockcode to group a pair
            for k in subset_pairs['StockCode'].unique():
                print('-' * 100)
                print(subset_pairs[subset_pairs['StockCode'] == k])
                print('-' * 100)
                print('-' * 100)
                
        # checking for negative quantities that have no matching positive quantities
        elif i < 0 and abs(i) not in df['Quantity'].unique():
            print ('There are cancellations in these quantities:', i)
        
            #checking stockcodes that have negative Quantity
            stockcode = list(df[df['Quantity'] == i]['StockCode'].unique())
            print('StockCodes that have negative Quantity:', stockcode)
        
            #subsetting the stockcodes that have negative Quantity and cancelled order
            subset_stockcode = df[df['StockCode'].isin(stockcode)]
            cancelled_order = subset_stockcode[subset_stockcode['Quantity'] == i]
        
            print('-' * 100)
            print(subset_stockcode)
            print('-' * 100)
            print(cancelled_order)
            print('-' * 100)
            print('-' * 100)

# %%
# Investigate cancellation scenarios for customer 15311

cust_15311 = sales_df[sales_df['CustomerID'] == '15311']
check_cancellations(cust_15311)
# Out:
# There are matching positive quantities for -1
# Stockcodes that have matching positive and negative quantities: ['35004C', '85047', '22198', '22197', '20829', '22571', '22778', '21258', '22646', '21668', '22774', '40001', '82483', '21313', '22171', '20712', '82001S', '21314', '22241', '85099B', '84978', '23206', '21033', '21929', '22386', '20724', '23199', '22384', '20728', '20727', '23089', '21530', '23169', '22411', '22845', '22681', '21559', '23146']
# ----------------------------------------------------------------------------------------------------
#       InvoiceNo StockCode                      Description  Quantity  \
# 154     C536383    35004C  SET OF 3 COLOURED  FLYING DUCKS        -1
# 18196   C537805    35004C  SET OF 3 COLOURED  FLYING DUCKS        -1
#
#               InvoiceDate  UnitPrice CustomerID  LineTotal
# 154   2018-11-29 09:49:00       4.65      15311      -4.65
# 18196 2018-12-06 13:18:00       4.65      15311      -4.65
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#       InvoiceNo StockCode                          Description  Quantity  \
# 18198   C537805     85047  WHITE BEADED GARLAND STRING 20LIGHT        -1
#
#               InvoiceDate  UnitPrice CustomerID  LineTotal
# 18198 2018-12-06 13:18:00       5.55      15311      -5.55
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#       InvoiceNo StockCode            Description  Quantity  \
# 18201   C537805     22198  LARGE POPCORN HOLDER         -1
#
#               InvoiceDate  UnitPrice CustomerID  LineTotal
# 18201 2018-12-06 13:18:00       1.45      15311      -1.45
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#        InvoiceNo StockCode           Description  Quantity  \
# 18202    C537805     22197  SMALL POPCORN HOLDER        -1
# 287233   C562097     22197        POPCORN HOLDER        -1
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal
# 18202  2018-12-06 13:18:00       0.72      15311      -0.72
# 287233 2019-07-31 13:19:00       0.72      15311      -0.72
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#        InvoiceNo StockCode                       Description  Quantity  \
# 18203    C537805     20829  GLITTER HANGING BUTTERFLY STRING        -1
# 161880   C550494     20829  GLITTER HANGING BUTTERFLY STRING        -1
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal
# 18203  2018-12-06 13:18:00       2.10      15311      -2.10
# 161880 2019-04-16 14:54:00       1.69      15311      -1.69
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#       InvoiceNo StockCode                   Description  Quantity  \
# 18204   C537805     22571  ROCKING HORSE RED CHRISTMAS         -1
#
#               InvoiceDate  UnitPrice CustomerID  LineTotal
# 18204 2018-12-06 13:18:00       0.85      15311      -0.85
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#        InvoiceNo StockCode                         Description  Quantity  \
# 21353     538076     22646  CERAMIC STRAWBERRY CAKE MONEY BANK         1
# 28607    C538650     22646  CERAMIC STRAWBERRY CAKE MONEY BANK        -1
# 195077   C553687     22646  CERAMIC STRAWBERRY CAKE MONEY BANK        -1
# 338480    566558     22646  CERAMIC STRAWBERRY CAKE MONEY BANK         1
# 350318    567626     22646  CERAMIC STRAWBERRY CAKE MONEY BANK         1
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal
# 21353  2018-12-07 14:15:00       1.45      15311       1.45
# 28607  2018-12-11 15:05:00       1.25      15311      -1.25
# 195077 2019-05-16 14:01:00       1.25      15311      -1.25
# 338480 2019-09-11 11:51:00       1.45      15311       1.45
# 350318 2019-09-19 12:56:00       1.45      15311       1.45
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#        InvoiceNo StockC
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#        InvoiceNo StockCode                   Description  Quantity  \
# 51782     540680    75049L  LARGE CIRCULAR MIRROR MOBILE         2
# 323460   C565305    75049L  LARGE CIRCULAR MIRROR MOBILE        -2
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal
# 51782  2019-01-08 16:24:00       1.25      15311        2.5
# 323460 2019-08-31 12:18:00       0.85      15311       -1.7
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#        InvoiceNo StockCode     Description  Quantity         InvoiceDate  \
# 59571     541293     20713  JUMBO BAG OWLS         2 2019-01-15 13:39:00
# 385514   C570203     20713  JUMBO BAG OWLS        -2 2019-10-05 16:49:00
#
#         UnitPrice CustomerID  LineTotal
# 59571        1.95      15311       3.90
# 385514       1.79      15311      -3.58
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#        InvoiceNo StockCode                        Description  Quantity  \
# 59574     541293     22411  JUMBO SHOPPER VINTAGE RED PAISLEY         2
# 66486     541798     22411  JUMBO SHOPPER VINTAGE RED PAISLEY         2
# 105791    545288     22411  JUMBO SHOPPER VINTAGE RED PAISLEY         2
# 145004    548863     22411  JUMBO SHOPPER VINTAGE RED PAISLEY         2
# 171664    551440     22411  JUMBO SHOPPER VINTAGE RED PAISLEY         2
# 468961   C576561     22411  JUMBO SHOPPER VINTAGE RED PAISLEY        -2
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal
# 59574  2019-01-15 13:39:00       1.95      15311       3.90
# 66486  2019-01-19 14:17:00       1.95      15311       3.90
# 105791 2019-02-27 11:48:00       1.95      15311       3.90
# 145004 2019-04-02 13:57:00       2.08      15311       4.16
# 171664 2019-04-26 15:29:00       2.08      15311       4.16
# 468961 2019-11-13 13:22:00       1.79      15311      -3.58
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#        InvoiceNo StockCode                     Description  Quantity  \
# 63542     541575    85099C  JUMBO  BAG BAROQUE BLACK WHITE         2
# 206497    554939    85099C  JUMBO  BAG BAROQUE BLACK WHITE         2
# 385510   C570203    85099C  JUMBO  BAG BAROQUE BLACK WHITE        -2
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal
# 63542  2019-01-17 13:21:00       1.95      15311       3.90
# 206497 2019-05-25 13:49:00       2.08      15311       4.16
# 385510 2019-10-05 16:49:00       1.79      15311      -3.58
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#       InvoiceNo StockCode                     Description  Quantity  \
# 78331   C542866     85063  CREAM SWEETHEART MAGAZINE RACK        -2
#
#               InvoiceDate  UnitPrice CustomerID  LineTotal
# 78331 2019-01-30 12:14:00      14.95      15311      -29.9
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#       InvoiceNo StockCode                 Description  Quantity  \
# 78332   C542866    35004G  SET OF 3 GOLD FLYING DUCKS        -2
#
#               InvoiceDate  UnitPrice CustomerID  LineTotal
# 78332 2019-01-30 12:14:00       1.95      15311       -3.9
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#       InvoiceNo StockCode                      Description  Quantity  \
# 78333   C542866    35004C  SET OF 3 COLOURED  FLYING DUCKS        -2
#
#               InvoiceDate  UnitPrice CustomerID  LineTotal
# 78333 2019-01-30 12:14:00       4.65      15311       -9.3
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#        InvoiceNo StockCode                       Description  Quantity  \
# 230960   C557224     84978  HANGING HEART JAR T-LIGHT HOLDER        -2
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal
# 230960 2019-06-15 13:22:00       1.06      15311      -2.12
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#        InvoiceNo StockCode              Description  Quantity  \
# 256142    559459     22386  JUMBO BAG PINK POLKADOT         2
# 385509   C570203     22386  JUMBO BAG PINK POLKADOT        -2
# 468959   C576561     22386  JUMBO BAG PINK POLKADOT        -2
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal
# 256142 2019-07-06 12:53:00       2.08      15311       4.16
# 385509 2019-10-05 16:49:00       1.79      15311      -3.58
# 468959 2019-11-13 13:22:00       1.79      15311      -3.58
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#        InvoiceNo StockCode                         Description  Quantity  \
# 287235   C562097     37449  CERAMIC CAKE STAND + HANGING CAKES        -2
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal
# 287235 2019-07-31 13:19:00        8.5      15311      -17.0
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#        InvoiceNo StockCode                          Description  Quantity  \
# 301378   C563258     22061  LARGE CAKE STAND  HANGING STRAWBERY        -2
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal
# 301378 2019-08-13 12:08:00        8.5      15311      -17.0
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#        InvoiceNo StockCode                        Description  Quantity  \
# 385506   C570203     71477  COLOUR GLASS. STAR T-LIGHT HOLDER        -2
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal
# 385506 2019-10-05 16:49:00       3.29      15311      -6.58
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#        InvoiceNo StockCode                   Description  Quantity  \
# 432240   C573864     23168  CLASSIC CAFE SUGAR DISPENSER        -2
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal
# 432240 2019-10-30 11:55:00       1.04      15311      -2.08
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#        InvoiceNo StockCode        Description  Quantity         InvoiceDate  \
# 432241   C573864     22467  GUMBALL COAT RACK        -2 2019-10-30 11:55:00
#
#         UnitPrice CustomerID  LineTotal
# 432241        2.1      15311       -4.2
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#        InvoiceNo StockCode                    Description  Quantity  \
# 468952   C576561     21314  SMALL GLASS HEART TRINKET POT        -2
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal
# 468952 2019-11-13 13:22:00       1.85      15311       -3.7
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# There are matching positive quantities for -3
# Stockcodes that have matching positive and negative quantities: ['22719', '35004C', '75049L', '40001', '22778']
# ----------------------------------------------------------------------------------------------------
#        InvoiceNo StockCode         Description  Quantity         InvoiceDate  \
# 138       536381     22778  GLASS CLOCHE SMALL         3 2018-11-29 09:41:00
# 468950   C576561     22778  GLASS CLOCHE SMALL        -3 2019-11-13 13:22:00
#
#         UnitPrice CustomerID  LineTotal
# 138          3.95      15311      11.85
# 468950       3.39      15311     -10.17
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#       InvoiceNo StockCode                   Description  Quantity  \
# 18199   C537805     22719  GUMBALL MONOCHROME COAT RACK        -3
#
#               InvoiceDate  UnitPrice CustomerID  LineTotal
# 18199 2018-12-06 13:18:00       1.06      15311      -3.18
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#       InvoiceNo StockCode                      Description  Quantity  \
# 39381   C539640    35004C  SET OF 3 COLOURED  FLYING DUCKS        -3
#
#               InvoiceDate  UnitPrice CustomerID  LineTotal
# 39381 2018-12-18 15:27:00       4.65      15311     -13.95
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#        InvoiceNo StockCode                   Description  Quantity  \
# 195076   C553687    75049L  LARGE CIRCULAR MIRROR MOBILE        -3
# 287232   C562097    75049L  LARGE CIRCULAR MIRROR MOBILE        -3
# 468953   C576561    75049L  LARGE CIRCULAR MIRROR MOBILE        -3
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal
# 195076 2019-05-16 14:01:00       0.85      15311      -2.55
# 287232 2019-07-31 13:19:00       0.85      15311      -2.55
# 468953 2019-11-13 13:22:00       0.85      15311      -2.55
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#        InvoiceNo StockCode                  Description  Quantity  \
# ...
# 30327    538857     22778  GLASS CLOCHE SMALL         4 2018-12-12 13:58:00
# 63497   C541573     22778  GLASS CLOCHE SMALL        -4 2019-01-17 12:47:00
#
#        UnitPrice CustomerID  LineTotal
# 30327       3.95      15311      15.80
# 63497       3.39      15311     -13.56
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#        InvoiceNo StockCode                   Description  Quantity  \
# 174677   C551841     22719  GUMBALL MONOCHROME COAT RACK        -4
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal
# 174677 2019-05-02 13:40:00       1.06      15311      -4.24
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#        InvoiceNo StockCode                   Description  Quantity  \
# 243320   C558444    75049L  LARGE CIRCULAR MIRROR MOBILE        -4
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal
# 243320 2019-06-27 13:29:00       0.85      15311       -3.4
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#        InvoiceNo StockCode                        Description  Quantity  \
# 328448    565776     22411  JUMBO SHOPPER VINTAGE RED PAISLEY         4
# 385511   C570203     22411  JUMBO SHOPPER VINTAGE RED PAISLEY        -4
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal
# 328448 2019-09-04 14:38:00       2.08      15311       8.32
# 385511 2019-10-05 16:49:00       1.79      15311      -7.16
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#        InvoiceNo StockCode                       Description  Quantity  \
# 373447    569330     23275  SET OF 3 HANGING OWLS OLLIE BEAK         4
# 468958   C576561     23275  SET OF 3 HANGING OWLS OLLIE BEAK        -4
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal
# 373447 2019-10-01 13:31:00       1.25      15311       5.00
# 468958 2019-11-13 13:22:00       1.04      15311      -4.16
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#        InvoiceNo StockCode               Description  Quantity  \
# 510077   C579415     23169  CLASSIC GLASS COOKIE JAR        -4
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal
# 510077 2019-11-27 12:52:00       3.75      15311      -15.0
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# There are matching positive quantities for -7
# Stockcodes that have matching positive and negative quantities: ['22778', '75049L']
# ----------------------------------------------------------------------------------------------------
#       InvoiceNo StockCode         Description  Quantity         InvoiceDate  \
# 70397   C542032     22778  GLASS CLOCHE SMALL        -7 2019-01-23 11:45:00
#
#        UnitPrice CustomerID  LineTotal
# 70397       3.39      15311     -23.73
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#        InvoiceNo StockCode                   Description  Quantity  \
# 161881   C550494    75049L  LARGE CIRCULAR MIRROR MOBILE        -7
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal
# 161881 2019-04-16 14:54:00       0.85      15311      -5.95
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# There are matching positive quantities for -6
# Stockcodes that have matching positive and negative quantities: ['22778']
# ----------------------------------------------------------------------------------------------------
#        InvoiceNo StockCode         Description  Quantity         InvoiceDate  \
# 109532   C545650     22778  GLASS CLOCHE SMALL        -6 2019-03-02 13:14:00
#
#         UnitPrice CustomerID  LineTotal
# 109532       3.39      15311     -20.34
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# There are matching positive quantities for -12
# Stockcodes that have matching positive and negative quantities: ['22171', '22844']
# ----------------------------------------------------------------------------------------------------
#        InvoiceNo StockCode                       Description  Quantity  \
# 66481     541798     22844  VINTAGE CREAM DOG FOOD CONTAINER        12
# 105797    545288     22844  VINTAGE CREAM DOG FOOD CONTAINER        12
# 305197   C563655     22844  VINTAGE CREAM DOG FOOD CONTAINER       -12
# 460585    575919     22844  VINTAGE CREAM DOG FOOD CONTAINER        12
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal
# 66481  2019-01-19 14:17:00       7.65      15311       91.8
# 105797 2019-02-27 11:48:00       7.65      15311       91.8
# 305197 2019-08-16 10:44:00       7.65      15311      -91.8
# 460585 2019-11-09 17:00:00       7.65      15311       91.8
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#        InvoiceNo StockCode                       Description  Quantity  \
# 99650     544777     22171  3 HOOK PHOTO SHELF ANTIQUE WHITE        12
# 119108    546528     22171  3 HOOK PHOTO SHELF ANTIQUE WHITE        12
# 120059   C546645     22171  3 HOOK PHOTO SHELF ANTIQUE WHITE       -12
# 460600    575919     22171  3 HOOK PHOTO SHELF ANTIQUE WHITE        12
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal
# 99650  2019-02-21 12:00:00       7.65      15311       91.8
# 119108 2019-03-12 13:04:00       7.65      15311       91.8
# 120059 2019-03-13 13:32:00       7.65      15311      -91.8
# 460600 2019-11-09 17:00:00       7.65      15311       91.8
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# There are matching positive quantities for -10
# Stockcodes that have matching positive and negative quantities: ['21314']
# ----------------------------------------------------------------------------------------------------
#        InvoiceNo StockCode                    Description  Quantity  \
# 144837   C548851     21314  SMALL GLASS HEART TRINKET POT       -10
# 144839    548856     21314  SMALL GLASS HEART TRINKET POT        10
# 144842   C548857     21314  SMALL GLASS HEART TRINKET POT       -10
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal
# 144837 2019-04-02 13:14:00       1.85      15311      -18.5
# 144839 2019-04-02 13:26:00       1.85      15311       18.5
# 144842 2019-04-02 13:28:00       1.85      15311      -18.5
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# There are matching positive quantities for -100
# Stockcodes that have matching positive and negative quantities: ['21035']
# ----------------------------------------------------------------------------------------------------
#        InvoiceNo StockCode                      Description  Quantity  \
# 151096    549542     21035  SET/2 RED RETROSPOT TEA TOWELS        100
# 151173   C549544     21035  SET/2 RED RETROSPOT TEA TOWELS       -100
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal
# 151096 2019-04-08 11:11:00       2.75      15311      275.0
# 151173 2019-04-08 11:15:00       2.75      15311     -275.0
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# There are matching positive quantities for -5
# Stockcodes that have matching positive and negative quantities: ['75049L', '85099B', '22778', '21314', '21258']
# ----------------------------------------------------------------------------------------------------
#        InvoiceNo StockCode                   Description  Quantity  \
# 230959   C557224    75049L  LARGE CIRCULAR MIRROR MOBILE        -5
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal
# 230959 2019-06-15 13:22:00       0.85      15311      -4.25
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#        InvoiceNo StockCode              Description  Quantity  \
# 230962   C557224    85099B  JUMBO BAG RED RETROSPOT        -5
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal
# 230962 2019-06-15 13:22:00       1.79      15311      -8.95
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#        InvoiceNo StockCode         Description  Quantity         InvoiceDate  \
# 230963   C557224     22778  GLASS CLOCHE SMALL        -5 2019-06-15 13:22:00
#
#         UnitPrice CustomerID  LineTotal
# 230963       3.39      15311     -16.95
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#        InvoiceNo StockCode                    Description  Quantity  \
# 243323   C558444     21314  SMALL GLASS HEART TRINKET POT        -5
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal
# 243323 2019-06-27 13:29:00       1.85      15311      -9.25
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#        InvoiceNo StockCode                 Description  Quantity  \
# 530911   C580886     21258  VICTORIAN SEWING BOX LARGE        -5
# 541715   C581568     21258  VICTORIAN SEWING BOX LARGE        -5
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal
# 530911 2019-12-04 12:25:00      10.95      15311     -54.75
# 541715 2019-12-07 11:57:00      10.95      15311     -54.75
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# There are matching positive quantities for -24
# Stockcodes that have matching positive and negative quantities: ['22778']
# ----------------------------------------------------------------------------------------------------
#        InvoiceNo StockCode         Description  Quantity         InvoiceDate  \
# 59544     541293     22778  GLASS CLOCHE SMALL        24 2019-01-15 13:39:00
# 85146     543463     22778  GLASS CLOCHE SMALL        24 2019-02-06 14:06:00
# 182813    552574     22778  GLASS CLOCHE SMALL        24 2019-05-08 12:20:00
# 216842    555855     22778  GLASS CLOCHE SMALL        24 2019-06-05 13:56:00
# 305198   C563655     22778  GLASS CLOCHE SMALL       -24 2019-08-16 10:44:00
#
#         UnitPrice CustomerID  LineTotal
# 59544        3.39      15311      81.36
# 85146        3.39      15311      81.36
# 182813       3.39      15311      81.36
# 216842       3.39      15311      81.36
# 305198       3.39      15311     -81.36
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# There are matching positive quantities for -48
# Stockcodes that have matching positive and negative quantities: ['47351B', '23165']
# ----------------------------------------------------------------------------------------------------
#        InvoiceNo StockCode                    Description  Quantity  \
# 262229    559905     23165  LARGE CERAMIC TOP STORAGE JAR        48
# 305200   C563655     23165  LARGE CERAMIC TOP STORAGE JAR       -48
# 393111    570797     23165  LARGE CERAMIC TOP STORAGE JAR        48
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal
# 262229 2019-07-11 13:27:00       1.45      15311       69.6
# 305200 2019-08-16 10:44:00       1.45      15311      -69.6
# 393111 2019-10-10 12:24:00       1.45      15311       69.6
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#        InvoiceNo StockCode            Description  Quantity  \
# 305117    563638    47351B  BLUE  VOILE LAMPSHADE        48
# 305199   C563655    47351B  BLUE  VOILE LAMPSHADE       -48
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal
# 305117 2019-08-16 10:36:00       2.55      15311      122.4
# 305199 2019-08-16 10:44:00       2.55      15311     -122.4
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# There are matching positive quantities for -9
# Stockcodes that have matching positive and negative quantities: ['40001']
# ----------------------------------------------------------------------------------------------------
#        InvoiceNo StockCode                  Description  Quantity  \
# 323459   C565305     40001  WHITE BAMBOO RIBS LAMPSHADE        -9
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal
# 323459 2019-08-31 12:18:00       0.64      15311      -5.76
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------

# %%
# Investigate cancellation scenarios for customer 17548

cust_17548 = sales_df[sales_df['CustomerID'] == '17548']
check_cancellations(cust_17548)
# Out:
# There are cancellations in these quantities: -12
# StockCodes that have negative Quantity: ['22556', '21484', '22557']
# ----------------------------------------------------------------------------------------------------
#     InvoiceNo StockCode                       Description  Quantity  \
# 235   C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 239   C536391     21484       CHICK GREY HOT WATER BOTTLE       -12
# 240   C536391     22557  PLASTERS IN TIN VINTAGE PAISLEY        -12
#
#             InvoiceDate  UnitPrice CustomerID  LineTotal
# 235 2018-11-29 10:24:00       1.65      17548      -19.8
# 239 2018-11-29 10:24:00       3.45      17548      -41.4
# 240 2018-11-29 10:24:00       1.65      17548      -19.8
# ----------------------------------------------------------------------------------------------------
#     InvoiceNo StockCode                       Description  Quantity  \
# 235   C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 239   C536391     21484       CHICK GREY HOT WATER BOTTLE       -12
# 240   C536391     22557  PLASTERS IN TIN VINTAGE PAISLEY        -12
#
#             InvoiceDate  UnitPrice CustomerID  LineTotal
# 235 2018-11-29 10:24:00       1.65      17548      -19.8
# 239 2018-11-29 10:24:00       3.45      17548      -41.4
# 240 2018-11-29 10:24:00       1.65      17548      -19.8
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# There are matching positive quantities for -24
# Stockcodes that have matching positive and negative quantities: ['21984', '21983', '21980', '22553', '22585']
# ----------------------------------------------------------------------------------------------------
#     InvoiceNo StockCode                       Description  Quantity  \
# 236   C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
#
#             InvoiceDate  UnitPrice CustomerID  LineTotal
# 236 2018-11-29 10:24:00       0.29      17548      -6.96
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#     InvoiceNo StockCode                       Description  Quantity  \
# 237   C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
#
#             InvoiceDate  UnitPrice CustomerID  LineTotal
# 237 2018-11-29 10:24:00       0.29      17548      -6.96
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#     InvoiceNo StockCode                        Description  Quantity  \
# 238   C536391     21980  PACK OF 12 RED RETROSPOT TISSUES        -24
#
#             InvoiceDate  UnitPrice CustomerID  LineTotal
# 238 2018-11-29 10:24:00       0.29      17548      -6.96
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#     InvoiceNo StockCode             Description  Quantity         InvoiceDate  \
# 241   C536391     22553  PLASTERS IN TIN SKULLS       -24 2018-11-29 10:24:00
#
#      UnitPrice CustomerID  LineTotal
# 241       1.65      17548      -39.6
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#        InvoiceNo StockCode                Description  Quantity  \
# 165024    550755     22585  PACK OF 6 BIRDY GIFT TAGS        24
# 177224   C552049     22585  PACK OF 6 BIRDY GIFT TAGS       -24
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal
# 165024 2019-04-18 12:01:00       1.25      17548       30.0
# 177224 2019-05-04 10:00:00       1.25      17548      -30.0
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# There are matching positive quantities for -4
# Stockcodes that have matching positive and negative quantities: ['22926']
# ----------------------------------------------------------------------------------------------------
#        InvoiceNo StockCode                     Description  Quantity  \
# 165028    550755     22926  IVORY GIANT GARDEN THERMOMETER         4
# 177223   C552049     22926  IVORY GIANT GARDEN THERMOMETER        -4
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal
# 165028 2019-04-18 12:01:00       5.95      17548       23.8
# 177223 2019-05-04 10:00:00       5.95      17548      -23.8
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# There are matching positive quantities for -10
# Stockcodes that have matching positive and negative quantities: ['22082', '22081', '22079']
# ----------------------------------------------------------------------------------------------------
#        InvoiceNo StockCode                  Description  Quantity  \
# 165025    550755     22082  RIBBON REEL STRIPES DESIGN         10
# 177225   C552049     22082  RIBBON REEL STRIPES DESIGN        -10
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal
# 165025 2019-04-18 12:01:00       1.65      17548       16.5
# 177225 2019-05-04 10:00:00       1.65      17548      -16.5
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#        InvoiceNo StockCode                 Description  Quantity  \
# 165026    550755     22081  RIBBON REEL FLORA + FAUNA         10
# 177226   C552049     22081  RIBBON REEL FLORA + FAUNA        -10
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal
# 165026 2019-04-18 12:01:00       1.65      17548       16.5
# 177226 2019-05-04 10:00:00       1.65      17548      -16.5
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#        InvoiceNo StockCode                 Description  Quantity  \
# 165027    550755     22079  RIBBON REEL HEARTS DESIGN         10
# 177227   C552049     22079  RIBBON REEL HEARTS DESIGN        -10
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal
# 165027 2019-04-18 12:01:00       1.65      17548       16.5
# 177227 2019-05-04 10:00:00       1.65      17548      -16.5
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------

# %%
# determine the number of records where Quantity < 0

len(sales_df[sales_df['Quantity'] < 0])
# Out:
# 9992

# %% [markdown]
# #### Observations/Assumptions:
# - The only way to find and check for cancellation scenarios is to do the search by customer
# - There are 8668 records where quantity < 0 and these records belong to 1535 customers which means we will have to apply the check_cancellations() function to 1535 customers and analyze the cancellation cases
# - It is not accurate to remove just the cancellations (records that have negative quantities) as this will result to overstatement of sales transactions
# - This is just to note that there are 4 cancellation scenarios in the data:
#   1. 1:1 match (original invoice and cancelled invoice that have the same stock_code and matching positive/negative quantities)
#   2. partial cancellations
#   3. cancellations without the corresponding original orders
#   4. original orders that were cancelled then placed the orders again

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 533652 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    533652 non-null  object
#  1   StockCode    533652 non-null  object
#  2   Description  533652 non-null  object
#  3   Quantity     533652 non-null  int64
#  4   InvoiceDate  533652 non-null  datetime64[ns]
#  5   UnitPrice    533652 non-null  float64
#  6   CustomerID   399689 non-null  object
#  7   LineTotal    533652 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 36.6+ MB

# %%
sales_df.describe()
# Out:
#             Quantity                    InvoiceDate      UnitPrice  \
# count  533652.000000                         533652  533652.000000
# mean        9.654949  2019-07-02 10:28:00.643452928       3.277232
# min    -80995.000000            2018-11-29 08:26:00       0.000000
# 25%         1.000000            2019-03-26 11:34:00       1.250000
# 50%         3.000000            2019-07-17 15:23:00       2.080000
# 75%        10.000000            2019-10-16 17:10:00       4.130000
# max     80995.000000            2019-12-07 12:50:00     649.500000
# std       219.688312                            NaN       4.507985
#
#            LineTotal
# count  533652.000000
# mean       18.309535
# min   -168469.600000
# 25%         3.750000
# 50%         9.840000
# 75%        17.400000
# max    168469.600000
# std       368.909494

# %%
# Create individual columns for date, period, day of the week, and hour

sales_df['Date'] = pd.to_datetime(sales_df['InvoiceDate']).dt.date
sales_df['Period'] = sales_df['InvoiceDate'].dt.to_period('M')
sales_df['Day'] = sales_df['InvoiceDate'].dt.day_name()
sales_df['Hour'] = sales_df['InvoiceDate'].dt.hour

sales_df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice CustomerID  LineTotal        Date   Period  \
# 0 2018-11-29 08:26:00       2.55      17850      15.30  2018-11-29  2018-11
# 1 2018-11-29 08:26:00       3.39      17850      20.34  2018-11-29  2018-11
# 2 2018-11-29 08:26:00       2.75      17850      22.00  2018-11-29  2018-11
# 3 2018-11-29 08:26:00       3.39      17850      20.34  2018-11-29  2018-11
# 4 2018-11-29 08:26:00       3.39      17850      20.34  2018-11-29  2018-11
#
#         Day  Hour
# 0  Thursday     8
# 1  Thursday     8
# 2  Thursday     8
# 3  Thursday     8
# 4  Thursday     8

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 533652 entries, 0 to 541908
# Data columns (total 12 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    533652 non-null  object
#  1   StockCode    533652 non-null  object
#  2   Description  533652 non-null  object
#  3   Quantity     533652 non-null  int64
#  4   InvoiceDate  533652 non-null  datetime64[ns]
#  5   UnitPrice    533652 non-null  float64
#  6   CustomerID   399689 non-null  object
#  7   LineTotal    533652 non-null  float64
#  8   Date         533652 non-null  object
#  9   Period       533652 non-null  period[M]
#  10  Day          533652 non-null  object
#  11  Hour         533652 non-null  int32
# dtypes: datetime64[ns](1), float64(2), int32(1), int64(1), object(6), period[M](1)
# memory usage: 50.9+ MB

# %%
sales_df.describe()
# Out:
#             Quantity                    InvoiceDate      UnitPrice  \
# count  533652.000000                         533652  533652.000000
# mean        9.654949  2019-07-02 10:28:00.643452928       3.277232
# min    -80995.000000            2018-11-29 08:26:00       0.000000
# 25%         1.000000            2019-03-26 11:34:00       1.250000
# 50%         3.000000            2019-07-17 15:23:00       2.080000
# 75%        10.000000            2019-10-16 17:10:00       4.130000
# max     80995.000000            2019-12-07 12:50:00     649.500000
# std       219.688312                            NaN       4.507985
#
#            LineTotal           Hour
# count  533652.000000  533652.000000
# mean       18.309535      13.078420
# min   -168469.600000       6.000000
# 25%         3.750000      11.000000
# 50%         9.840000      13.000000
# 75%        17.400000      15.000000
# max    168469.600000      20.000000
# std       368.909494       2.447198

# %%
sales_df.describe(include='object')
# Out:
#        InvoiceNo StockCode                         Description CustomerID  \
# count     533652    533652                              533652     399689
# unique     25284      4037                                4199       4363
# top       573585    85123A  WHITE HANGING HEART T-LIGHT HOLDER      17841
# freq        1112      2301                                2357       7800
#
#               Date     Day
# count       533652  533652
# unique         305       6
# top     2019-12-03  Friday
# freq          5273  102483

# %%
sales_df[sales_df['Description'] == 'unknown']
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 622       536414     22139     unknown        56 2018-11-29 11:52:00
# 1970      536545     21134     unknown         1 2018-11-29 14:32:00
# 1971      536546     22145     unknown         1 2018-11-29 14:33:00
# 1972      536547     37509     unknown         1 2018-11-29 14:33:00
# 1987      536549    85226A     unknown         1 2018-11-29 14:34:00
# ...          ...       ...         ...       ...                 ...
# 535322    581199     84581     unknown        -2 2019-12-05 18:26:00
# 535326    581203     23406     unknown        15 2019-12-05 18:31:00
# 535332    581209     21620     unknown         6 2019-12-05 18:35:00
# 536981    581234     72817     unknown        27 2019-12-06 10:33:00
# 538554    581408     85175     unknown        20 2019-12-06 14:06:00
#
#         UnitPrice CustomerID  LineTotal        Date   Period       Day  Hour
# 622           0.0        NaN        0.0  2018-11-29  2018-11  Thursday    11
# 1970          0.0        NaN        0.0  2018-11-29  2018-11  Thursday    14
# 1971          0.0        NaN        0.0  2018-11-29  2018-11  Thursday    14
# 1972          0.0        NaN        0.0  2018-11-29  2018-11  Thursday    14
# 1987          0.0        NaN        0.0  2018-11-29  2018-11  Thursday    14
# ...           ...        ...        ...         ...      ...       ...   ...
# 535322        0.0        NaN       -0.0  2019-12-05  2019-12  Thursday    18
# 535326        0.0        NaN        0.0  2019-12-05  2019-12  Thursday    18
# 535332        0.0        NaN        0.0  2019-12-05  2019-12  Thursday    18
# 536981        0.0        NaN        0.0  2019-12-06  2019-12    Friday    10
# 538554        0.0        NaN        0.0  2019-12-06  2019-12    Friday    14
#
# [1439 rows x 12 columns]

# %%
stock_code_desc = sales_df.groupby(['StockCode'])['Description'].nunique().reset_index()
stock_code_desc[stock_code_desc['Description'] > 1]
# Out:
#      StockCode  Description
# 0        10002            2
# 1        10080            3
# 3       10123C            2
# 8        10133            2
# 12       15030            2
# ...        ...          ...
# 3985    90200C            2
# 4003    90209B            2
# 4004    90209C            2
# 4007    90210C            2
# 4008    90210D            2
#
# [1315 rows x 2 columns]

# %%
sales_df[sales_df['StockCode'] == '85184C']
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 615       536412    85184C    S/4 VALENTINE DECOUPAGE HEART BOX         1
# 4058      536745    85184C    S/4 VALENTINE DECOUPAGE HEART BOX        12
# 23090     538177    85184C    S/4 VALENTINE DECOUPAGE HEART BOX         1
# 27410     538541    85184C    S/4 VALENTINE DECOUPAGE HEART BOX        24
# 27900     538566    85184C    S/4 VALENTINE DECOUPAGE HEART BOX         1
# ...          ...       ...                                  ...       ...
# 523209    580503    85184C  SET 4 VALENTINE DECOUPAGE HEART BOX         1
# 525523    580632    85184C  SET 4 VALENTINE DECOUPAGE HEART BOX         2
# 527084    580692    85184C  SET 4 VALENTINE DECOUPAGE HEART BOX         2
# 536023    581217    85184C  SET 4 VALENTINE DECOUPAGE HEART BOX         1
# 539348    581439    85184C  SET 4 VALENTINE DECOUPAGE HEART BOX         1
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal        Date  \
# 615    2018-11-29 11:49:00       2.95      17920       2.95  2018-11-29
# 4058   2018-11-30 13:38:00       2.95      17235      35.40  2018-11-30
# 23090  2018-12-08 09:51:00       5.91        NaN       5.91  2018-12-08
# 27410  2018-12-11 10:46:00       1.25      17428      30.00  2018-12-11
# 27900  2018-12-11 11:21:00       5.91        NaN       5.91  2018-12-11
# ...                    ...        ...        ...        ...         ...
# 523209 2019-12-02 13:20:00       2.95      13956       2.95  2019-12-02
# 525523 2019-12-03 12:16:00       2.95      16360       5.90  2019-12-03
# 527084 2019-12-03 15:51:00       2.95      13173       5.90  2019-12-03
# 536023 2019-12-06 09:20:00       5.79        NaN       5.79  2019-12-06
# 539348 2019-12-06 16:30:00       5.79        NaN       5.79  2019-12-06
#
#          Period       Day  Hour
# 615     2018-11  Thursday    11
# 4058    2018-11    Friday    13
# 23090   2018-12  Saturday     9
# 27410   2018-12   Tuesday    10
# 27900   2018-12   Tuesday    11
# ...         ...       ...   ...
# 523209  2019-12    Monday    13
# 525523  2019-12   Tuesday    12
# 527084  2019-12   Tuesday    15
# 536023  2019-12    Friday     9
# 539348  2019-12    Friday    16
#
# [194 rows x 12 columns]

# %%
sales_df['Description'].value_counts()
# Out:
# Description
# WHITE HANGING HEART T-LIGHT HOLDER    2357
# REGENCY CAKESTAND 3 TIER              2189
# JUMBO BAG RED RETROSPOT               2156
# PARTY BUNTING                         1720
# LUNCH BAG RED RETROSPOT               1625
#                                       ...
# sold with wrong barcode                  1
# LARGE HEART FLOWERS HOOK                 1
# BLUE DROP EARRINGS W BEAD CLUSTER        1
# PURPLE ANEMONE ARTIFICIAL FLOWER         1
# showroom                                 1
# Name: count, Length: 4199, dtype: int64

# %%
# Load the preprocessed dataframe to a .pkl file in local folder

sales_df.to_pickle("C:/Users/offic/OneDrive/Desktop/product data analysis/sales_df.pkl")

# %%
# Load the preprocessed sales_df dataframe to a csv file for dashboard purposes

sales_df.to_csv("C:/Users/offic/OneDrive/Desktop/product data analysis/sales_df", index = False)

# %% [markdown]
# <a id='EDA'></a>
# ## Exploratory Data Analysis

# %%
sales_df = pd.read_pickle("C:/Users/offic/OneDrive/Desktop/product data analysis/sales_df.pkl")
sales_df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice CustomerID  LineTotal        Date   Period  \
# 0 2018-11-29 08:26:00       2.55      17850      15.30  2018-11-29  2018-11
# 1 2018-11-29 08:26:00       3.39      17850      20.34  2018-11-29  2018-11
# 2 2018-11-29 08:26:00       2.75      17850      22.00  2018-11-29  2018-11
# 3 2018-11-29 08:26:00       3.39      17850      20.34  2018-11-29  2018-11
# 4 2018-11-29 08:26:00       3.39      17850      20.34  2018-11-29  2018-11
#
#         Day  Hour
# 0  Thursday     8
# 1  Thursday     8
# 2  Thursday     8
# 3  Thursday     8
# 4  Thursday     8

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 533652 entries, 0 to 541908
# Data columns (total 12 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    533652 non-null  object
#  1   StockCode    533652 non-null  object
#  2   Description  533652 non-null  object
#  3   Quantity     533652 non-null  int64
#  4   InvoiceDate  533652 non-null  datetime64[ns]
#  5   UnitPrice    533652 non-null  float64
#  6   CustomerID   399689 non-null  object
#  7   LineTotal    533652 non-null  float64
#  8   Date         533652 non-null  object
#  9   Period       533652 non-null  period[M]
#  10  Day          533652 non-null  object
#  11  Hour         533652 non-null  int32
# dtypes: datetime64[ns](1), float64(2), int32(1), int64(1), object(6), period[M](1)
# memory usage: 50.9+ MB

# %%
# Transaction coverage

print(sales_df['Date'].min())
print(sales_df['Date'].max())
# Out:
# 2018-11-29
# 2019-12-07

# %% [markdown]
# ### 1. Sales Performance Summary
# - Total number of customers
# - Total number of orders
# - Total units sold
# - Total revenue
# - Average order value
# - Total number of unique products
# - Total number of orders without customer id

# %%
num_customers = sales_df['CustomerID'].nunique()
num_orders = sales_df['InvoiceNo'].nunique()
units_sold = sales_df['Quantity'].sum()
total_revenue = sales_df['LineTotal'].sum()
ave_order_value = sales_df['LineTotal'].sum() / sales_df['InvoiceNo'].nunique()
unique_prod = sales_df['StockCode'].nunique()
orders_no_custid = sales_df[sales_df['CustomerID'].isnull()]['InvoiceNo'].nunique()

print(f'Total number of customers is {num_customers}')
print(f'Total number of orders is {num_orders}')
print(f'Total number of units sold: {units_sold}')
print(f'Total revenue or GMV: ${total_revenue/1000000: .2f} M')
print(f'Average order value: {ave_order_value: .2f}')
print(f'Total number of unique products: {unique_prod}')
print(f'Total number of orders without customer id: {orders_no_custid}')
# Out:
# Total number of customers is 4363
# Total number of orders is 25284
# Total number of units sold: 5152383
# Total revenue or GMV: $ 9.77 M
# Average order value:  386.45
# Total number of unique products: 4037
# Total number of orders without customer id: 3496

# %% [markdown]
# ### 2. Top-performing Customers
# - Based on sales
# - Based on quantity purchased

# %%
# Top 10 customers based on sales

top10_cust = sales_df.groupby(['CustomerID'])['LineTotal'].sum().sort_values(ascending = False)[:10]
              
plt.figure(figsize = [15, 8])
base_color = sns.color_palette()[0]
ax = sns.barplot(x = top10_cust.index, y = top10_cust.values, color = base_color)
ax.tick_params(axis = 'both', labelsize = 10)
ax.bar_label(ax.containers[0], padding = 3)

plt.title('Top 10 Highest-performing Customers based on Sales', size = 20)
plt.xlabel('Customers', size = 15)
plt.ylabel('Sales', size = 15)
plt.show;

# %%
# Top 10 customers based on quantity purchased

top10_cust_qty = sales_df.groupby(['CustomerID'])['Quantity'].sum().sort_values(ascending = False)[:10]
              
plt.figure(figsize = [15, 8])
base_color = sns.color_palette()[0]
ax = sns.barplot(x = top10_cust_qty.index, y = top10_cust_qty.values, color = base_color)
ax.tick_params(axis = 'both', labelsize = 10)
ax.bar_label(ax.containers[0], padding = 3)

plt.title('Top 10 Highest-performing Customers based on Quantity Purchased', size = 20)
plt.xlabel('Customers', size = 15)
plt.ylabel('Quantity', size = 15)
plt.show;

# %%
# Customer 14646 Spend Overtime

cust_14646 = sales_df[sales_df['CustomerID'] == '14646'].groupby(['Period'])['LineTotal'].sum().reset_index()

plt.figure(figsize = [12, 8])
# convert period to datetime as seaborn and matplotlib don't support line plotting with period datatype
sns.lineplot(data=cust_14646, x = cust_14646['Period'].astype(str), y = 'LineTotal', color = 'gray', marker = 'o')

plt.title('Top Performing Customer(14646) Spend Over Time', fontsize = 15)
plt.xlabel('Period', size = 12)
plt.ylabel('Spend', size = 12)
plt.show()

# %%
# Favorite products of customer 14646

cust_14646_prod = sales_df[sales_df['CustomerID'] == '14646']\
                    .groupby(['Description'])['LineTotal']\
                    .sum()\
                    .sort_values(ascending = False)[:10]

plt.figure(figsize = [15, 8])
base_color = sns.color_palette()[0]
ax = sns.barplot(x = cust_14646_prod.index, y = cust_14646_prod.values, color = base_color)
ax.tick_params(axis = 'both', labelsize = 10)
ax.bar_label(ax.containers[0], padding = 3)

plt.title('Top 10 Favorite Products of Customer 14646', size = 20)
plt.xlabel('Product', size = 15)
plt.ylabel('Sales', size = 15)
plt.xticks(rotation=75)
plt.show;

# %% [markdown]
# ### 3. Top-performing Products
# - Based on sales
# - Based on quantity purchased

# %%
# Top 10 products based on sales

top10_prod = sales_df.groupby(['Description'])['LineTotal'].sum().sort_values(ascending = False)[:10]
              
plt.figure(figsize = [15, 8])
base_color = sns.color_palette()[0]
ax = sns.barplot(x = top10_prod.index, y = top10_prod.values, color = base_color)
ax.tick_params(axis = 'both', labelsize = 10)
ax.bar_label(ax.containers[0], padding = 3)

plt.title('Top 10 Highest-performing Products based on Sales', size = 20)
plt.xlabel('Product', size = 15)
plt.ylabel('Sales', size = 15)
plt.xticks(rotation=75)
plt.show;

# %%
# Top 10 products based on quantity sold

top10_prod_qty = sales_df.groupby(['Description'])['Quantity'].sum().sort_values(ascending = False)[:10]
              
plt.figure(figsize = [15, 8])
base_color = sns.color_palette()[0]
ax = sns.barplot(x = top10_prod_qty.index, y = top10_prod_qty.values, color = base_color)
ax.tick_params(axis = 'both', labelsize = 10)
ax.bar_label(ax.containers[0], padding = 3)

plt.title('Top 10 Highest-performing Products based on Units Sold', size = 20)
plt.xlabel('Product', size = 15)
plt.ylabel('Quantity', size = 15)
plt.xticks(rotation=80)
plt.show;

# %%
# REGENCY CAKESTAND 3 TIER Sales Overtime

regency = sales_df[sales_df['Description'] == 'REGENCY CAKESTAND 3 TIER'].groupby(['Period'])['LineTotal'].sum().reset_index()

plt.figure(figsize = [12, 8])
# convert period to datetime as seaborn and matplotlib don't support line plotting with period datatype
sns.lineplot(data=regency, x = regency['Period'].astype(str), y = 'LineTotal', color = 'gray', marker = 'o')

plt.title('Top Performing Product(REGENCY CAKESTAND) Sales Over Time', fontsize = 15)
plt.xlabel('Period', size = 12)
plt.ylabel('Sales', size = 12)
plt.show()

# %%
# Top 10 customers with largest spend on Regency Cakestand

regency_cust = sales_df[sales_df['Description'] == 'REGENCY CAKESTAND 3 TIER']\
                    .groupby(['CustomerID'])['LineTotal']\
                    .sum()\
                    .sort_values(ascending = False)[:10]

plt.figure(figsize = [15, 8])
base_color = sns.color_palette()[0]
ax = sns.barplot(x = regency_cust.index, y = regency_cust.values, color = base_color)
ax.tick_params(axis = 'both', labelsize = 10)
ax.bar_label(ax.containers[0], padding = 3)

plt.title('Top 10 Customers with the Largest Purchase of Regency Cakestand', size = 20)
plt.xlabel('Customer', size = 15)
plt.ylabel('Sales - Regency Cakestand', size = 15)
plt.show;

# %% [markdown]
# ### 4. Sales Performance and Quantity Sold Over Time

# %%
# Monthly sales and units sold (line plots)

monthly_perf = sales_df.groupby(['Period']).agg({
                                                'LineTotal': 'sum',
                                                'Quantity': 'sum'}).reset_index()
plt.figure(figsize = [20, 5])
ax = sns.lineplot(data = monthly_perf)
plt.show()

# %%
# Monthly sales and units sold (side by side bar plots)


monthly_perf.plot(kind='bar', x = 'Period', figsize = (15, 8))
plt.title('Sales and Units Sold Over Time', fontsize = 20)
plt.xlabel('Period', fontsize = 15)
plt.ylabel('Sales / Units Sold', fontsize = 15)
plt.legend(['Sales', 'Units Sold'])
plt.rcParams["axes.formatter.limits"] = (0, 1400000)
plt.xticks(rotation = 360)
plt.show()

# %% [markdown]
# ### 5. Statistical relationships between quantity, price, line total, and hour

# %%
# create a correlation plot between numerical variables
num_var = sales_df.select_dtypes(include=['int','float']).columns.tolist()

plt.figure(figsize = [10, 5])
sns.heatmap(sales_df[num_var].corr(), annot = True, fmt = '.2f', cmap = 'vlag_r', center = 0)
plt.show()

# %% [markdown]
# The correlation plot shows the following:
# 1. There is a very strong positive correlation between LineTotal and Quantity, which suggests that larger quantities purchased result to higher sales and smaller quatities result to lower sales.
# 2. There is a very weak positive correlation between UnitPrice and LineTotal. This suggests that high-priced product don't necessarily result to higher sales or low-priced products don't necessarily result to lower sales.
# 3. There is also a very weak positive correlation between UnitPrice and Hour. This suggests that high-priced products are not necessarily purchased later in the day or low-priced products earlier in the day.
# 4. There is a very weak negative correlation between UnitPrice and Quantity. This suggests that high-priced products are not necessarily purchased less than their low-priced counterparts.

# %% [markdown]
# ### 6. Daily Number of Orders and Total Sales

# %%
# Daily number of orders

daily_perf = sales_df.groupby(['Date']).agg({
                                    'InvoiceNo': 'nunique',
                                    'LineTotal': 'sum'})

daily_perf['InvoiceNo'].plot(kind = 'line', linewidth = 2, figsize = (15, 10))
plt.title('Daily Orders', fontsize = 15)
plt.xlabel('Date', fontsize = 12)
plt.ylabel('Orders', fontsize = 12)
plt.show()

# %%
# Daily Sales

daily_perf['LineTotal'].plot(kind = 'line', linewidth = 2, figsize = (15, 10))
plt.title('Daily Sales', fontsize = 15)
plt.xlabel('Date', fontsize = 12)
plt.ylabel('Sales', fontsize = 12)
plt.show()

# %% [markdown]
# ### 7. Which day of the week has the highest number of orders?

# %%
weekday_perf = sales_df.groupby(['Day']).agg({
                                            'InvoiceNo': 'nunique',
                                            'LineTotal': 'sum'}).reset_index()

plt.figure(figsize = [20, 8])
base_color = sns.color_palette()[0]
order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']

ax = sns.barplot(x = weekday_perf['Day'], y = weekday_perf['InvoiceNo'], color = base_color, order = order)
ax.tick_params(axis = 'both', which = 'major', labelsize = 15)
ax.bar_label(ax.containers[0], padding = 3, size = 12)

plt.title('Total Orders per Day of the Week', size = 20)
plt.xlabel('Day of the Week', size = 15)
plt.ylabel('Number of Orders', size = 15)
plt.show();

# %% [markdown]
# ### 8. Which day of the week has the highest sales?

# %%
plt.figure(figsize = [20, 8])
base_color = sns.color_palette()[0]
order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']

ax = sns.barplot(x = weekday_perf['Day'], y = round(weekday_perf['LineTotal']/1000000, 2), color = base_color, order = order)
ax.tick_params(axis = 'both', which = 'major', labelsize = 15)
ax.bar_label(ax.containers[0], padding = 3, size = 12)

plt.title('Total Sales per Day of the Week', size = 20)
plt.xlabel('Day of the Week', size = 15)
plt.ylabel('Total Sales in M', size = 15)
plt.show();

# %% [markdown]
# ### 9. Which time of the day has the highest number of orders?

# %%
# Total Orders at different Times of the Day

hourly_perf = sales_df.groupby(['Hour']).agg({
    
                                            'InvoiceNo': 'nunique',
                                            'LineTotal': 'sum'}).reset_index()

plt.figure(figsize = [20, 8])
base_color = sns.color_palette()[0]


ax = sns.barplot(x = hourly_perf['Hour'], y = hourly_perf['InvoiceNo'], color = base_color)
ax.tick_params(axis = 'both', which = 'major', labelsize = 15)
ax.bar_label(ax.containers[0], padding = 3, size = 12)

plt.title('Total Orders at different Times of the Day', size = 20)
plt.xlabel('Time of the Day', size = 15)
plt.ylabel('Number of Orders', size = 15)
plt.show();

# %% [markdown]
# ### 10. Which time of the day has the highest sales?

# %%
# Total Sales at different Times of the Day

plt.figure(figsize = [20, 8])
base_color = sns.color_palette()[0]

ax = sns.barplot(x = hourly_perf['Hour'], y = hourly_perf['LineTotal'], color = base_color)
ax.tick_params(axis = 'both', which = 'major', labelsize = 15)
ax.bar_label(ax.containers[0], padding = 3, size = 12, fmt = '%d') # annotates bar plots with labels without scientific notation

plt.title('Total Sales at different Times of the Day', size = 20)
plt.xlabel('Time of the Day', size = 15)
plt.ylabel('Total Sales', size = 15)
plt.show();

# %%
# Create a dataframe for cancelled orders

cancelled_orders = sales_df[sales_df['Quantity'] < 0]
cancelled_orders
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 154      C536383    35004C    SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556     PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984   PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983   PACK OF 12 BLUE PAISLEY TISSUES        -24
# 238      C536391     21980  PACK OF 12 RED RETROSPOT TISSUES        -24
# ...          ...       ...                                ...       ...
# 540448   C581490     22178    VICTORIAN GLASS HANGING T-LIGHT       -12
# 540449   C581490     23144    ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541715   C581568     21258         VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978   HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979      36 PENCILS TUBE RED RETROSPOT        -5
#
#                InvoiceDate  UnitPrice CustomerID  LineTotal        Date  \
# 154    2018-11-29 09:49:00       4.65      15311      -4.65  2018-11-29
# 235    2018-11-29 10:24:00       1.65      17548     -19.80  2018-11-29
# 236    2018-11-29 10:24:00       0.29      17548      -6.96  2018-11-29
# 237    2018-11-29 10:24:00       0.29      17548      -6.96  2018-11-29
# 238    2018-11-29 10:24:00       0.29      17548      -6.96  2018-11-29
# ...                    ...        ...        ...        ...         ...
# 540448 2019-12-07 09:57:00       1.95      14397     -23.40  2019-12-07
# 540449 2019-12-07 09:57:00       0.83      14397      -9.13  2019-12-07
# 541715 2019-12-07 11:57:00      10.95      15311     -54.75  2019-12-07
# 541716 2019-12-07 11:58:00       1.25      17315      -1.25  2019-12-07
# 541717 2019-12-07 11:58:00       1.25      17315      -6.25  2019-12-07
#
#          Period       Day  Hour
# 154     2018-11  Thursday     9
# 235     2018-11  Thursday    10
# 236     2018-11  Thursday    10
# 237     2018-11  Thursday    10
# 238     2018-11  Thursday    10
# ...         ...       ...   ...
# 540448  2019-12  Saturday     9
# 540449  2019-12  Saturday     9
# 541715  2019-12  Saturday    11
# 541716  2019-12  Saturday    11
# 541717  2019-12  Saturday    11
#
# [9992 rows x 12 columns]

# %%
# Load the cancelled orders dataframe to a csv file for dashboard purposes

cancelled_orders.to_csv('../data/cancelled_orders.csv', index = False)

# %% [markdown]
# ### 11. Which products have the higest amount of cancelled orders?

# %%
prod_cancelled_amt = cancelled_orders.groupby(['Description'])['LineTotal'].sum().sort_values()[:10]

plt.figure(figsize = [15, 12])
base_color = sns.color_palette()[5]

ax = sns.barplot(x = prod_cancelled_amt.values, y = prod_cancelled_amt.index, color=base_color)
plt.title("Top 10 Product Cancellation based on Amount", size=20)
plt.xlabel("Total Amount of Cancelled Orders", size=10)
plt.ylabel("Product", size=10)
ax.bar_label(ax.containers[0])
plt.show();

# %% [markdown]
# ### 12. Which products have the largest units of cancelled orders?

# %%
prod_cancelled_qty = cancelled_orders.groupby(['Description'])['Quantity'].sum().sort_values()[:10]

plt.figure(figsize = [15, 12])
base_color = sns.color_palette()[5]

ax = sns.barplot(x = prod_cancelled_qty.values, y = prod_cancelled_qty.index, color=base_color)
plt.title("Top 10 Product Cancellation based on Quantity", size=20)
plt.xlabel("Total Units of Cancelled Orders", size=10)
plt.ylabel("Product", size=10)
ax.bar_label(ax.containers[0])
plt.show();

# %% [markdown]
# ### 13. What are the most frequently returned products?

# %%
freq_returns = cancelled_orders.groupby(['Description'])['InvoiceNo'].nunique().sort_values(ascending=False)[:10]

plt.figure(figsize = [15, 12])
base_color = sns.color_palette()[0]

ax = sns.barplot(x = freq_returns.values, y = freq_returns.index, color=base_color)
plt.title("Top 10 Most Frequently Cancelled Products", size=20)
plt.xlabel("Frequency", size=10)
plt.ylabel("Product", size=10)
ax.bar_label(ax.containers[0])
plt.show();

# %% [markdown]
# ### 14. Who are the customers with the highest amount of cancelled orders?

# %%
cust_cancelled_amt = cancelled_orders.groupby(['CustomerID'])['LineTotal'].sum().sort_values()[:10]

plt.figure(figsize = [15, 12])
base_color = sns.color_palette()[5]

ax = sns.barplot(x = cust_cancelled_amt.index, y = cust_cancelled_amt.values, color=base_color)
plt.title("Top 10 Customers with the Highest Amount of Cancelled Orders", size=20)
plt.xlabel("Customer", size=10)
plt.ylabel("Total Amount of Cancelled Orders", size=10)
ax.bar_label(ax.containers[0])
plt.show();

# %% [markdown]
# ### 15. Who are the customers with the largest quantity of cancelled orders?

# %%
cust_cancelled_qty = cancelled_orders.groupby(['CustomerID'])['Quantity'].sum().sort_values()[:10]

plt.figure(figsize = [15, 12])
base_color = sns.color_palette()[5]

ax = sns.barplot(x = cust_cancelled_qty.index, y = cust_cancelled_qty.values, color=base_color)
plt.title("Top 10 Customers with the Largest Quantity of Cancelled Orders", size=20)
plt.xlabel("Customer", size=10)
plt.ylabel("Quantity of Cancelled Orders", size=10)
ax.bar_label(ax.containers[0])
plt.show();

# %% [markdown]
# ### 16. Which customers haved cancelled their orders most frequently?

# %%
plt.figure(figsize = [15, 12])
base_color = sns.color_palette()[0]

ax = sns.barplot(x = cancelled_orders['CustomerID'].value_counts().values[:10], \
                 y = cancelled_orders['CustomerID'].value_counts().index[:10], color=base_color)
plt.title("Top 10 Customers who haved cancelled their orders most frequently", size=20)
plt.xlabel("Frequency", size=10)
plt.ylabel("Customer", size=10)
ax.bar_label(ax.containers[0])
plt.show();

# %% [markdown]
# ### 18. Which months have the highest amount of cancelled orders?

# %%
monthly_returns_amt = cancelled_orders.groupby(['Period'])['LineTotal'].sum()

plt.figure(figsize = [15, 12])
base_color = sns.color_palette()[5]

ax = sns.barplot(x = monthly_returns_amt.index, y = monthly_returns_amt.values, color=base_color)
plt.title("Monthly Cancelled Orders in $", size=20)
plt.xlabel("Month", size=10)
plt.ylabel("Total Amount of Cancelled Orders", size=10)
ax.bar_label(ax.containers[0])
plt.show();

# %% [markdown]
# ### 17. Which months have the largest quantity of cancelled orders?

# %%
monthly_returns_qty = cancelled_orders.groupby(['Period'])['Quantity'].sum()

plt.figure(figsize = [15, 12])
base_color = sns.color_palette()[5]

ax = sns.barplot(x = monthly_returns_qty.index, y = monthly_returns_qty.values, color=base_color)
plt.title("Monthly Cancelled Orders in Units", size=20)
plt.xlabel("Month", size=10)
plt.ylabel("Total Quantity of Cancelled Orders", size=10)
ax.bar_label(ax.containers[0])
plt.show();
